# %% [markdown]
# Two general strategies of unifying benchmark:
# -

# %%
# !git clone https://github.com/Urdatorn/norma-syllabarum-graecarum.git
# Out:
# Klonar till "norma-syllabarum-graecarum"...
# remote: Enumerating objects: 255, done.
# remote: Counting objects: 100% (255/255), done.
# remote: Compressing objects: 100% (167/167), done.
# remote: Total 255 (delta 120), reused 203 (delta 72), pack-reused 0 (from 0)
# Tar emot objekt: 100% (255/255), 172,91 KiB | 2,08 MiB/s, klart.
# Analyserar delta: 100% (120/120), klart.

# %% [markdown]
# # Eric's original bench comparison

# %%
import os
import re
import torch
from collections import defaultdict
from torch.nn.functional import softmax
from transformers import PreTrainedTokenizerFast, RobertaForTokenClassification

from syllagreek_utils import preprocess_greek_line, syllabify_joined

# -------- Load Model --------
# Point to your trained RoBERTa checkpoint
model_path = "Ericu950/macronizer_mini"

tokenizer: PreTrainedTokenizerFast = PreTrainedTokenizerFast.from_pretrained(model_path)
model: RobertaForTokenClassification = RobertaForTokenClassification.from_pretrained(
    model_path,
    torch_dtype=torch.bfloat16 if torch.cuda.is_available() else torch.float32
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

# Respect model's positional limit (RoBERTa uses <s> and </s> as 2 specials)
max_len = min(
    getattr(tokenizer, "model_max_length", 512),
    getattr(model.config, "max_position_embeddings", 514) - 2
)
if max_len <= 0:
    max_len = 512  # fallback

# -------- Helper: parse gold labels in files --------
def extract_expected_pattern(line):
    """
    Input line may contain:
      [ ... ] = expected H
      { ... } = expected L
      plain   = unlabeled (ignored)
    Returns raw_input (no brackets) and sequence of expected labels for syllables only in brackets.
    """
    expected_labels = []
    tokens = []

    pattern = re.compile(r'(\[[^]]+\])|(\{[^}]+\})|([^\[\]\{\}]+)')
    for match in pattern.finditer(line):
        if match.group(1):
            content = match.group(1)[1:-1]
            tokens.append(content)
            expected_labels.append("H")
        elif match.group(2):
            content = match.group(2)[1:-1]
            tokens.append(content)
            expected_labels.append("L")
        elif match.group(3):
            content = match.group(3)
            tokens.append(content)

    raw_input = ''.join(tokens)
    return raw_input, expected_labels

# -------- Rule-based backup (unchanged) --------
def classify_syllables(syllables, clear_mask):
    definitely_heavy_set = set("ὖὗἆἇἶἷήηωώἠἡἢἣἤἥἦἧὠὡὢὣὤὥὦὧὴὼᾄᾅᾆᾇᾐᾑᾔᾕᾖᾗᾠᾤᾦᾧᾳᾴᾶᾷῂῃῄῆῇῖῦῲῳῴῶῷ")
    ambiguous_set = set("ΐάίΰαιυϊϋύἀἁἂἃἄἅἰἱἲἳἴἵὐὑὓὔὕὰῒὶὺ")
    light_set = set("έεοόἐἑἓἔἕὀὁὂὃὄὅὲὸ")

    mute_consonants = set("βγδθκπτφχ")
    nonmute_consonants = set("λρμν")
    sigma = set("σ")
    all_consonants = mute_consonants | nonmute_consonants | sigma

    def token_contains(token, char_set):
        return any(ch in char_set for ch in token)

    def get_nucleus(syl):
        nucleus_chars = [ch for token in syl for ch in token if ch not in all_consonants]
        return ''.join(nucleus_chars) if nucleus_chars else None

    def classify_single_syllable(syl, next_syl):
        full_syllable = "".join(syl)
        nucleus = get_nucleus(syl)
        if nucleus is None:
            return "light"

        if len(nucleus) >= 2:
            base_class = "heavy"
        elif token_contains(nucleus, definitely_heavy_set):
            base_class = "heavy"
        elif token_contains(nucleus, ambiguous_set):
            base_class = "ambiguous"
        elif token_contains(nucleus, light_set):
            base_class = "light"
        else:
            base_class = "light"

        final_char = syl[-1][-1]

        if base_class == "heavy":
            return "heavy"
        elif base_class == "ambiguous":
            if final_char in nonmute_consonants:
                return "heavy"
            if final_char in mute_consonants and next_syl is not None:
                next_onset = next_syl[0][0]
                if next_onset not in nonmute_consonants:
                    return "heavy"
            return "muta cum liquida"
        elif base_class == "light":
            if final_char in nonmute_consonants or final_char in sigma:
                return "heavy"
            elif final_char in mute_consonants and next_syl is not None:
                next_onset = next_syl[0][0]
                if next_onset in nonmute_consonants:
                    return "muta cum liquida"
                else:
                    return "heavy"
            else:
                return "light"

    classifications = []
    for i, syl in enumerate(syllables):
        if not clear_mask[i]:
            classifications.append(None)
            continue
        next_syl = syllables[i+1] if i < len(syllables) - 1 else None
        syl_class = classify_single_syllable(syl, next_syl)
        classifications.append(syl_class)

    return classifications

# %%
# -------- Inference: map predictions back to syllables --------
def predict_syllable_weights(raw_line):
    # Your utils should return preprocessed tokens and their syllabification
    tokens = preprocess_greek_line(raw_line)
    syllables = syllabify_joined(tokens)  # list[str], one syllable per element

    # Encode using syllables as pre-split "words"
    enc = tokenizer(
        syllables,
        is_split_into_words=True,
        return_tensors="pt",
        truncation=True,
        max_length=max_len,
        padding=False  # avoid masking every sequence to max_len
    )

    # Remove token_type_ids if present (RoBERTa doesn't use them)
    enc.pop("token_type_ids", None)

    enc = {k: v.to(device) for k, v in enc.items()}

    with torch.no_grad():
        outputs = model(**enc)
        logits = outputs.logits  # [1, seq_len, num_labels]
        probs = softmax(logits, dim=-1)
        pred_ids = torch.argmax(probs, dim=-1)[0].cpu().tolist()

    # Align back to syllables via word_ids
    # For a single example, use the fast tokenizer's word_ids()
    word_ids = tokenizer(
        syllables,
        is_split_into_words=True,
        truncation=True,
        max_length=max_len,
        add_special_tokens=True,
        return_offsets_mapping=False
    ).word_ids()

    aligned_preds = []
    syllable_index = 0
    for i, wid in enumerate(word_ids):
        if wid is None:
            continue  # special tokens like <s>, </s>
        if wid != syllable_index:
            # If tokenizer ever produced more than one token per syllable (shouldn't happen with WordLevel),
            # this keeps only the first; adjust if you want a different policy (e.g., majority).
            syllable_index = wid
        if syllable_index < len(syllables):
            aligned_preds.append((syllables[syllable_index], pred_ids[i]))

    # Trim to actual syllables length (in case truncation kicked in)
    aligned_preds = aligned_preds[:len(syllables)]

    only_sylls = [s for s, _ in aligned_preds]
    labels = [l for _, l in aligned_preds]

    # 0 = "use rules" (as in your previous script), 1 = H, 2 = L  (adapt if your mapping differs)
    clear_mask = [l == 0 for l in labels]

    # For the rule-based fallback we need character-level syllables
    syllables_tokenized = [[ch for ch in syl] for syl in only_sylls]
    rule_based = classify_syllables(syllables_tokenized, clear_mask)

    # Merge: if model says 1→H, 2→L, 0→use rule
    final_labels = []
    for model_label, rule in zip(labels, rule_based):
        if model_label == 1:
            final_labels.append("H")
        elif model_label == 2:
            final_labels.append("L")
        elif model_label == 0:
            final_labels.append("H" if rule == "heavy" else "L" if rule == "light" else None)
        else:
            final_labels.append(None)

    return final_labels

# -------- Evaluation Loop --------
data_dir = "norma-syllabarum-graecarum/final"
results = defaultdict(lambda: {"H_correct": 0, "H_total": 0, "L_correct": 0, "L_total": 0, "all_correct": 0, "all_total": 0})

for filename in os.listdir(data_dir):
    if not filename.endswith(".txt"):
        continue

    filepath = os.path.join(data_dir, filename)
    with open(filepath, encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line or line.startswith("#"):
                continue

            raw_input, expected = extract_expected_pattern(line)
            predicted = predict_syllable_weights(raw_input)

            for exp, pred in zip(expected, predicted):
                if pred is None:
                    continue
                results[filename]["all_total"] += 1
                results[filename][f"{exp}_total"] += 1
                if exp == pred:
                    results[filename]["all_correct"] += 1
                    results[filename][f"{exp}_correct"] += 1

# -------- Reporting --------
overall = defaultdict(int)

print(f"\n{'File':<30} {'All Acc':>8} {'H Acc':>8} {'L Acc':>8}")
print("-" * 60)
for file, data in sorted(results.items()):
    all_acc = data["all_correct"] / data["all_total"] if data["all_total"] else 0
    h_acc = data["H_correct"] / data["H_total"] if data["H_total"] else 0
    l_acc = data["L_correct"] / data["L_total"] if data["L_total"] else 0

    print(f"{file:<30} {all_acc:8.2%} {h_acc:8.2%} {l_acc:8.2%}")

    for k in data:
        overall[k] += data[k]

# -------- Overall Accuracy --------
print("\nOverall Accuracy:")
all_acc = overall["all_correct"] / overall["all_total"] if overall["all_total"] else 0
h_acc = overall["H_correct"] / overall["H_total"] if overall["H_total"] else 0
l_acc = overall["L_correct"] / overall["L_total"] if overall["L_total"] else 0
print(f"{'All':<10}: {all_acc:.2%}")
print(f"{'Heavy':<10}: {h_acc:.2%}")
print(f"{'Light':<10}: {l_acc:.2%}")
# Out:
# File                            All Acc    H Acc    L Acc
# ------------------------------------------------------------
# acharnenses.txt                  95.61%   95.33%   95.92%
# contracelsum.txt                 96.94%   94.91%  100.00%
# cratylus.txt                     96.12%   93.37%  100.00%
# cyclops.txt                      96.27%   94.37%   98.99%
# dionysiaca.txt                   96.33%   93.06%   99.36%
# dioscorides.txt                  93.52%   86.96%   98.39%
# enchiridion.txt                  95.81%   92.93%   99.38%
# insolem.txt                      93.33%   92.72%   94.03%
# norma_aristophanis_canticorum.txt   94.97%   93.54%   96.74%
# oedipus.txt                      95.76%   94.33%   97.89%
# partheneion.txt                  87.39%   80.88%   97.67%
# plutarchus.txt                   96.18%   94.12%   98.84%
# quintus.txt                      92.08%   89.21%   94.51%
# supplices.txt                    88.66%   88.46%   88.89%
# thucydides.txt                   95.97%   92.35%  100.00%
#
# Overall Accuracy:
# All       : 94.99%
# Heavy     : 93.35%
# Light     : 97.00%

# %% [markdown]
# - *All 100% L texts are prose* => Prose is easier for the macronizer (not surprising)
# - Doric (`partheneion`) is predictably the hardest ("alphacizing" => more hard dichrona)

# %% [markdown]
# # Version that saves failing words

# %%
import os
import re
import torch
from tqdm import tqdm
from collections import defaultdict
from torch.nn.functional import softmax
from transformers import PreTrainedTokenizerFast, RobertaForTokenClassification

from syllagreek_utils import preprocess_greek_line, syllabify_joined

model_path = "Ericu950/macronizer_mini"

tokenizer: PreTrainedTokenizerFast = PreTrainedTokenizerFast.from_pretrained(model_path)
model: RobertaForTokenClassification = RobertaForTokenClassification.from_pretrained(
    model_path,
    torch_dtype=torch.bfloat16 if torch.cuda.is_available() else torch.float32
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

max_len = min(
    getattr(tokenizer, "model_max_length", 512),
    getattr(model.config, "max_position_embeddings", 514) - 2
)
if max_len <= 0:
    max_len = 512

# -------- Helper: parse gold labels in files --------
def extract_expected_pattern(line):
    expected_labels = []
    tokens = []
    pattern = re.compile(r'(\[[^]]+\])|(\{[^}]+\})|([^\[\]\{\}]+)') # 3 groups: 1. [ ... ] bracketed sections, 2. { ... } brace sections, 3. everything else in between
    for match in pattern.finditer(line):
        if match.group(1):
            content = match.group(1)[1:-1]
            tokens.append(content)
            expected_labels.append("H")
        elif match.group(2):
            content = match.group(2)[1:-1]
            tokens.append(content)
            expected_labels.append("L")
        elif match.group(3):
            tokens.append(match.group(3))
    raw_input = ''.join(tokens)
    return raw_input, expected_labels

# -------- Rule-based backup (unchanged) --------
def classify_syllables(syllables, clear_mask):
    definitely_heavy_set = set("ὖὗἆἇἶἷήηωώἠἡἢἣἤἥἦἧὠὡὢὣὤὥὦὧὴὼᾄᾅᾆᾇᾐᾑᾔᾕᾖᾗᾠᾤᾦᾧᾳᾴᾶᾷῂῃῄῆῇῖῦῲῳῴῶῷ")
    ambiguous_set = set("ΐάίΰαιυϊϋύἀἁἂἃἄἅἰἱἲἳἴἵὐὑὓὔὕὰῒὶὺ")
    light_set = set("έεοόἐἑἓἔἕὀὁὂὃὄὅὲὸ")
    mute_consonants = set("βγδθκπτφχ")
    nonmute_consonants = set("λρμν")
    sigma = set("σ")
    all_consonants = mute_consonants | nonmute_consonants | sigma

    def token_contains(token, char_set):
        return any(ch in char_set for ch in token)

    def get_nucleus(syl):
        nucleus_chars = [ch for token in syl for ch in token if ch not in all_consonants]
        return ''.join(nucleus_chars) if nucleus_chars else None

    def classify_single_syllable(syl, next_syl):
        nucleus = get_nucleus(syl)
        if nucleus is None:
            return "light"

        if len(nucleus) >= 2:
            base_class = "heavy"
        elif token_contains(nucleus, definitely_heavy_set):
            base_class = "heavy"
        elif token_contains(nucleus, ambiguous_set):
            base_class = "ambiguous"
        elif token_contains(nucleus, light_set):
            base_class = "light"
        else:
            base_class = "light"

        final_char = syl[-1][-1]

        if base_class == "heavy":
            return "heavy"
        elif base_class == "ambiguous":
            if final_char in nonmute_consonants:
                return "heavy"
            if final_char in mute_consonants and next_syl is not None:
                next_onset = next_syl[0][0]
                if next_onset not in nonmute_consonants:
                    return "heavy"
            return "muta cum liquida"
        elif base_class == "light":
            if final_char in nonmute_consonants or final_char in sigma:
                return "heavy"
            elif final_char in mute_consonants and next_syl is not None:
                next_onset = next_syl[0][0]
                if next_onset in nonmute_consonants:
                    return "muta cum liquida"
                else:
                    return "heavy"
            else:
                return "light"

    classifications = []
    for i, syl in enumerate(syllables):
        if not clear_mask[i]:
            classifications.append(None)
            continue
        next_syl = syllables[i+1] if i < len(syllables) - 1 else None
        classifications.append(classify_single_syllable(syl, next_syl))
    return classifications

# -------- Inference: map predictions back to syllables --------
def predict_syllable_weights(raw_line):
    tokens = preprocess_greek_line(raw_line)
    syllables = syllabify_joined(tokens)

    enc = tokenizer(
        syllables,
        is_split_into_words=True,
        return_tensors="pt",
        truncation=True,
        max_length=max_len,
        padding=False
    )
    enc.pop("token_type_ids", None)
    enc = {k: v.to(device) for k, v in enc.items()}

    with torch.no_grad():
        outputs = model(**enc)
        probs = softmax(outputs.logits, dim=-1) # dim=-1 means "the last dim" of the tensor, e.g. in [[[0,1],[2,3]]] we softmax [0,1] & [2,3]
        pred_ids = torch.argmax(probs, dim=-1)[0].cpu().tolist()

    word_ids = tokenizer(
        syllables,
        is_split_into_words=True,
        truncation=True,
        max_length=max_len,
        add_special_tokens=True,
        return_offsets_mapping=False
    ).word_ids()

    aligned_preds = []
    syllable_index = 0
    for i, wid in enumerate(word_ids):
        if wid is None:
            continue
        if wid != syllable_index:
            syllable_index = wid
        if syllable_index < len(syllables):
            aligned_preds.append((syllables[syllable_index], pred_ids[i]))

    aligned_preds = aligned_preds[:len(syllables)]
    only_sylls = [s for s, _ in aligned_preds]
    labels = [l for _, l in aligned_preds]

    clear_mask = [l == 0 for l in labels]
    syllables_tokenized = [[ch for ch in syl] for syl in only_sylls]
    rule_based = classify_syllables(syllables_tokenized, clear_mask)

    final_labels = []
    for model_label, rule in zip(labels, rule_based):
        if model_label == 1:
            final_labels.append("H")
        elif model_label == 2:
            final_labels.append("L")
        elif model_label == 0:
            final_labels.append("H" if rule == "heavy" else "L" if rule == "light" else None)
        else:
            final_labels.append(None)
    return final_labels

# ---------------------------------------------------------------------------
# -------- Evaluation Loop (TSV failing sentences with line numbers) --------
# ---------------------------------------------------------------------------

gold_dir = "norma-syllabarum-graecarum/final"
pred_dir = "norma_macronizer_mini"
failed_sentences_dir = "failed_sentences"
os.makedirs(failed_sentences_dir, exist_ok=True)

results = defaultdict(lambda: {
    "H_correct":0, "H_total":0,
    "L_correct":0, "L_total":0,
    "all_correct":0, "all_total":0,
    "failed_sentences":[]  # stores tuples: (gold_line, linenr)
})

for filename in tqdm(os.listdir(gold_dir)):
    if not filename.endswith(".txt"):
        continue
    gold_path = os.path.join(gold_dir, filename)
    pred_path = os.path.join(pred_dir, filename)

    # Load predicted lines once
    if os.path.exists(pred_path):
        with open(pred_path, encoding="utf-8") as pf:
            pred_lines = [l.strip() for l in pf.readlines()]
    else:
        pred_lines = []

    with open(gold_path, encoding="utf-8") as gf:
        for linenr, line in enumerate(gf, start=1):
            line = line.strip()
            if not line or line.startswith("#"):
                continue

            raw_input, expected = extract_expected_pattern(line)
            predicted_labels = predict_syllable_weights(raw_input)

            # Stats
            for exp, pred_lbl in zip(expected, predicted_labels):
                if pred_lbl is None:
                    continue
                results[filename]["all_total"] += 1
                results[filename][f"{exp}_total"] += 1
                if exp == pred_lbl:
                    results[filename]["all_correct"] += 1
                    results[filename][f"{exp}_correct"] += 1

            # Record failing lines
            fully_correct = all(
                (p == e or p is None) for p, e in zip(predicted_labels, expected)
            )
            if not fully_correct:
                results[filename]["failed_sentences"].append((line, linenr))

    # Write TSV
    outpath = os.path.join(failed_sentences_dir, filename.replace(".txt","_failed_sentences.tsv"))
    with open(outpath, "w", encoding="utf-8") as out:
        out.write("gold_sentence\tline_number\tpredicted_sentence\n")
        for gold_line, linenr in results[filename]["failed_sentences"]:
            if linenr-1 < len(pred_lines):
                pred_line = pred_lines[linenr-1]
            else:
                pred_line = ""
            out.write(f"{gold_line.replace('[', '').replace(']', '').replace('{', '').replace('}', '')}\t{linenr}\t{pred_line}\n")

# -------- Reporting (unchanged) --------
overall = defaultdict(int)
print(f"\n{'File':<30} {'All Acc':>8} {'H Acc':>8} {'L Acc':>8}")
print("-"*60)
for file, data in sorted(results.items()):
    all_acc = data["all_correct"]/data["all_total"] if data["all_total"] else 0
    h_acc = data["H_correct"]/data["H_total"] if data["H_total"] else 0
    l_acc = data["L_correct"]/data["L_total"] if data["L_total"] else 0
    print(f"{file:<30} {all_acc:8.2%} {h_acc:8.2%} {l_acc:8.2%}")
    for k in ["all_correct","all_total","H_correct","H_total","L_correct","L_total"]:
        overall[k] += data[k]

print("\nOverall Accuracy:")
all_acc = overall["all_correct"]/overall["all_total"] if overall["all_total"] else 0
h_acc = overall["H_correct"]/overall["H_total"] if overall["H_total"] else 0
l_acc = overall["L_correct"]/overall["L_total"] if overall["L_total"] else 0
print(f"{'All':<10}: {all_acc:.2%}")
print(f"{'Heavy':<10}: {h_acc:.2%}")
print(f"{'Light':<10}: {l_acc:.2%}")
# Out:
# 100%|██████████| 16/16 [00:04<00:00,  3.50it/s]
# File                            All Acc    H Acc    L Acc
# ------------------------------------------------------------
# acharnenses.txt                  95.61%   95.33%   95.92%
# contracelsum.txt                 96.94%   94.91%  100.00%
# cratylus.txt                     96.12%   93.37%  100.00%
# cyclops.txt                      96.27%   94.37%   98.99%
# dionysiaca.txt                   96.33%   93.06%   99.36%
# dioscorides.txt                  93.52%   86.96%   98.39%
# enchiridion.txt                  95.81%   92.93%   99.38%
# insolem.txt                      93.33%   92.72%   94.03%
# norma_aristophanis_canticorum.txt   94.97%   93.54%   96.74%
# oedipus.txt                      95.76%   94.33%   97.89%
# partheneion.txt                  87.39%   80.88%   97.67%
# plutarchus.txt                   96.18%   94.12%   98.84%
# quintus.txt                      92.08%   89.21%   94.51%
# supplices.txt                    88.66%   88.46%   88.89%
# thucydides.txt                   95.97%   92.35%  100.00%
#
# Overall Accuracy:
# All       : 94.99%
# Heavy     : 93.35%
# Light     : 97.00%

# %%
import os
import re
import torch
from tqdm import tqdm
from collections import defaultdict
from torch.nn.functional import softmax
from transformers import PreTrainedTokenizerFast, RobertaForTokenClassification

from syllagreek_utils import preprocess_greek_line, syllabify_joined

# -------- Load model --------
model_path = "Ericu950/macronizer_mini"

print(f"Benchmarking {model_path} on Norma Syllabarum Graecarum...")

tokenizer: PreTrainedTokenizerFast = PreTrainedTokenizerFast.from_pretrained(model_path)
model: RobertaForTokenClassification = RobertaForTokenClassification.from_pretrained(
    model_path,
    torch_dtype=torch.bfloat16 if torch.cuda.is_available() else torch.float32
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

max_len = min(
    getattr(tokenizer, "model_max_length", 512),
    getattr(model.config, "max_position_embeddings", 514) - 2
)
if max_len <= 0:
    max_len = 512

# -------- Helper: parse gold labels in files --------
def extract_expected_pattern(line):
    expected_labels = []
    tokens = []
    pattern = re.compile(r'(\[[^]]+\])|(\{[^}]+\})|([^\[\]\{\}]+)')  # 3 groups: [..], {..}, other
    for match in pattern.finditer(line):
        if match.group(1):
            content = match.group(1)[1:-1]
            tokens.append(content)
            expected_labels.append("H")
        elif match.group(2):
            content = match.group(2)[1:-1]
            tokens.append(content)
            expected_labels.append("L")
        elif match.group(3):
            tokens.append(match.group(3))
    raw_input = ''.join(tokens)
    return raw_input, expected_labels

# -------- Rule-based syllable classification --------
def classify_syllables(syllables, clear_mask):
    definitely_heavy_set = set("ὖὗἆἇἶἷήηωώἠἡἢἣἤἥἦἧὠὡὢὣὤὥὦὧὴὼᾄᾅᾆᾇᾐᾑᾔᾕᾖᾗᾠᾤᾦᾧᾳᾴᾶᾷῂῃῄῆῇῖῦῲῳῴῶῷ")
    ambiguous_set = set("ΐάίΰαιυϊϋύἀἁἂἃἄἅἰἱἲἳἴἵὐὑὓὔὕὰῒὶὺ")
    light_set = set("έεοόἐἑἓἔἕὀὁὂὃὄὅὲὸ")
    mute_consonants = set("βγδθκπτφχ")
    nonmute_consonants = set("λρμν")
    sigma = set("σ")
    all_consonants = mute_consonants | nonmute_consonants | sigma

    def token_contains(token, char_set):
        return any(ch in char_set for ch in token)

    def get_nucleus(syl):
        nucleus_chars = [ch for token in syl for ch in token if ch not in all_consonants]
        return ''.join(nucleus_chars) if nucleus_chars else None

    def classify_single_syllable(syl, next_syl):
        nucleus = get_nucleus(syl)
        if nucleus is None:
            return "light"

        if len(nucleus) >= 2:
            base_class = "heavy"
        elif token_contains(nucleus, definitely_heavy_set):
            base_class = "heavy"
        elif token_contains(nucleus, ambiguous_set):
            base_class = "ambiguous"
        elif token_contains(nucleus, light_set):
            base_class = "light"
        else:
            base_class = "light"

        final_char = syl[-1][-1]

        if base_class == "heavy":
            return "heavy"
        elif base_class == "ambiguous":
            if final_char in nonmute_consonants:
                return "heavy"
            if final_char in mute_consonants and next_syl is not None:
                next_onset = next_syl[0][0]
                if next_onset not in nonmute_consonants:
                    return "heavy"
            return "muta cum liquida"
        elif base_class == "light":
            if final_char in nonmute_consonants or final_char in sigma:
                return "heavy"
            elif final_char in mute_consonants and next_syl is not None:
                next_onset = next_syl[0][0]
                if next_onset in nonmute_consonants:
                    return "muta cum liquida"
                else:
                    return "heavy"
            else:
                return "light"

    classifications = []
    for i, syl in enumerate(syllables):
        if not clear_mask[i]:
            classifications.append(None)
            continue
        next_syl = syllables[i+1] if i < len(syllables) - 1 else None
        classifications.append(classify_single_syllable(syl, next_syl))
    return classifications

# -------- Predict syllable weights --------
def predict_syllable_weights(raw_line):
    tokens = preprocess_greek_line(raw_line)
    syllables = syllabify_joined(tokens)

    enc = tokenizer(
        syllables,
        is_split_into_words=True,
        return_tensors="pt",
        truncation=True,
        max_length=max_len,
        padding=False
    )
    enc.pop("token_type_ids", None)
    enc = {k: v.to(device) for k, v in enc.items()}

    with torch.no_grad():
        outputs = model(**enc)
        probs = softmax(outputs.logits, dim=-1)
        pred_ids = torch.argmax(probs, dim=-1)[0].cpu().tolist()

    word_ids = tokenizer(
        syllables,
        is_split_into_words=True,
        truncation=True,
        max_length=max_len,
        add_special_tokens=True,
        return_offsets_mapping=False
    ).word_ids()

    aligned_preds = []
    syllable_index = 0
    for i, wid in enumerate(word_ids):
        if wid is None:
            continue
        if wid != syllable_index:
            syllable_index = wid
        if syllable_index < len(syllables):
            aligned_preds.append((syllables[syllable_index], pred_ids[i]))

    aligned_preds = aligned_preds[:len(syllables)]
    only_sylls = [s for s, _ in aligned_preds]
    labels = [l for _, l in aligned_preds]

    clear_mask = [l == 0 for l in labels]
    syllables_tokenized = [[ch for ch in syl] for syl in only_sylls]
    rule_based = classify_syllables(syllables_tokenized, clear_mask)

    final_labels = []
    for model_label, rule in zip(labels, rule_based):
        if model_label == 1:
            final_labels.append("H")
        elif model_label == 2:
            final_labels.append("L")
        elif model_label == 0:
            final_labels.append("H" if rule == "heavy" else "L" if rule == "light" else None)
        else:
            final_labels.append(None)
    return final_labels

# ---------------------------------------------------------------------------
# -------- Evaluation Loop (compute predictions on the fly) -----------------
# ---------------------------------------------------------------------------

gold_dir = "norma-syllabarum-graecarum/final"
failed_sentences_dir = "failed_sentences"
failed_words_dir = "failed_words"
os.makedirs(failed_sentences_dir, exist_ok=True)
os.makedirs(failed_words_dir, exist_ok=True)

results = defaultdict(lambda: {
    "H_correct":0, "H_total":0,
    "L_correct":0, "L_total":0,
    "all_correct":0, "all_total":0,
    "failed_sentences":[]  # stores tuples: (gold_line, linenr)
})

failed_rows = []

for filename in tqdm(os.listdir(gold_dir)):
    if not filename.endswith(".txt"):
        continue
    gold_path = os.path.join(gold_dir, filename)

    with open(gold_path, encoding="utf-8") as gf:
        for linenr, line in enumerate(gf, start=1):
            line = line.strip()
            if not line or line.startswith("#"):
                continue

            raw_input, expected = extract_expected_pattern(line)
            predicted_labels = predict_syllable_weights(raw_input)

            # Stats
            for exp, pred_lbl in zip(expected, predicted_labels):
                if pred_lbl is None:
                    continue
                results[filename]["all_total"] += 1
                results[filename][f"{exp}_total"] += 1
                if exp == pred_lbl:
                    results[filename]["all_correct"] += 1
                    results[filename][f"{exp}_correct"] += 1

            # Record failing sentences
            fully_correct = all((p == e or p is None) for p, e in zip(predicted_labels, expected))
            if not fully_correct:
                results[filename]["failed_sentences"].append((line, linenr))

                # ---- Build TSV rows for failed words ----
                gold_pattern_str = ''.join(expected)
                pred_pattern_str = ''.join([p if p else "-" for p in predicted_labels])

                # Build syllable-to-word mapping
                syll_to_word = []
                words = re.findall(r'\S+', re.sub(r'[\[\]\{\}]', '', raw_input))
                for word in words:
                    word_sylls = syllabify_joined(preprocess_greek_line(word))
                    syll_to_word.extend([word] * len(word_sylls))

                # Find failing syllables
                failed_indices = [i for i, (g_lbl, p_lbl) in enumerate(zip(expected, predicted_labels)) if p_lbl != g_lbl and p_lbl is not None]

                # Map each failing syllable to its word (once per word)
                failed_words_seen = set()
                for idx in failed_indices:
                    if idx >= len(syll_to_word):
                        continue
                    failed_word = syll_to_word[idx]
                    if failed_word in failed_words_seen:
                        continue
                    failed_words_seen.add(failed_word)
                    failed_rows.append((failed_word, raw_input, gold_pattern_str, pred_pattern_str))

# Write TSV for failed words
outpath_words = os.path.join(failed_words_dir, "failed_words.tsv")
with open(outpath_words, "w", encoding="utf-8") as out:
    out.write("failed_word\tgold_line\tgold_pattern\tpredicted_pattern\n")
    for row in failed_rows:
        out.write("\t".join(row) + "\n")

# Write TSVs for failed sentences (line-wise)
for filename, data in results.items():
    outpath_sent = os.path.join(failed_sentences_dir, filename.replace(".txt","_failed_sentences.tsv"))
    with open(outpath_sent, "w", encoding="utf-8") as out:
        out.write("gold_sentence\tline_number\tpredicted_sentence\n")
        for gold_line, linenr in data["failed_sentences"]:
            # full predicted pattern string for reference
            pred_labels = predict_syllable_weights(extract_expected_pattern(gold_line)[0])
            pred_line_str = ''.join([p if p else "-" for p in pred_labels])
            out.write(f"{gold_line.replace('[','').replace(']','').replace('{','').replace('}','')}\t{linenr}\t{pred_line_str}\n")

# -------- Reporting (unchanged) --------
overall = defaultdict(int)
print(f"\n{'File':<30} {'All Acc':>8} {'H Acc':>8} {'L Acc':>8}")
print("-"*60)
for file, data in sorted(results.items()):
    all_acc = data["all_correct"]/data["all_total"] if data["all_total"] else 0
    h_acc = data["H_correct"]/data["H_total"] if data["H_total"] else 0
    l_acc = data["L_correct"]/data["L_total"] if data["L_total"] else 0
    print(f"{file:<30} {all_acc:8.2%} {h_acc:8.2%} {l_acc:8.2%}")
    for k in ["all_correct","all_total","H_correct","H_total","L_correct","L_total"]:
        overall[k] += data[k]

print("\nOverall Accuracy:")
all_acc = overall["all_correct"]/overall["all_total"] if overall["all_total"] else 0
h_acc = overall["H_correct"]/overall["H_total"] if overall["H_total"] else 0
l_acc = overall["L_correct"]/overall["L_total"] if overall["L_total"] else 0
print(f"{'All':<10}: {all_acc:.2%}")
print(f"{'Heavy':<10}: {h_acc:.2%}")
print(f"{'Light':<10}: {l_acc:.2%}")
# Out:
# Benchmarking Ericu950/macronizer_mini on Norma Syllabarum Graecarum...
# 100%|██████████| 16/16 [00:05<00:00,  3.17it/s]
# File                            All Acc    H Acc    L Acc
# ------------------------------------------------------------
# acharnenses.txt                  95.61%   95.33%   95.92%
# contracelsum.txt                 96.94%   94.91%  100.00%
# cratylus.txt                     96.12%   93.37%  100.00%
# cyclops.txt                      96.27%   94.37%   98.99%
# dionysiaca.txt                   96.33%   93.06%   99.36%
# dioscorides.txt                  93.52%   86.96%   98.39%
# enchiridion.txt                  95.81%   92.93%   99.38%
# insolem.txt                      93.33%   92.72%   94.03%
# norma_aristophanis_canticorum.txt   94.97%   93.54%   96.74%
# oedipus.txt                      95.76%   94.33%   97.89%
# partheneion.txt                  87.39%   80.88%   97.67%
# plutarchus.txt                   96.18%   94.12%   98.84%
# quintus.txt                      92.08%   89.21%   94.51%
# supplices.txt                    88.66%   88.46%   88.89%
# thucydides.txt                   95.97%   92.35%  100.00%
#
# Overall Accuracy:
# All       : 94.99%
# Heavy     : 93.35%
# Light     : 97.00%

# %% [markdown]
# # New unified string-comparison bench algorithm

# %% [markdown]
# Ovan benchmark är stavelseviktsbaserad!! Bör vara vokallängdsbaserad. Förenkling: funktion som "skyfflar om" ^/_ i macronizer-mini:s norma till att ligga efter närmast föregående vokal, så att den kan jämföras enkelt med gold, på samma sätt som existerande macronizern.

# %%
import re
from grc_utils import DICHRONA

# What to not count as permutation: whitespace + punctuation
PUNCT_WHITESPACE = re.compile(r'[\s\u0387\u037e\u00b7\.,!?;:\"()\[\]{}<>«»\-—…|⏑⏓†×]')

def _is_punct(ch: str) -> bool:
    return bool(PUNCT_WHITESPACE.match(ch))

def _slide_left_over_punct(chars, i):
    """
    Move chars[i] left across any contiguous punctuation/whitespace
    by swapping in-place. Return the new index of the diacritic.
    """
    while i > 0 and _is_punct(chars[i - 1]):
        chars[i - 1], chars[i] = chars[i], chars[i - 1]
        i -= 1
    return i

def markup_after_dichrona(string: str) -> str:
    """
    Ensure every ^/_ follows a char in DICHRONA.

    Algorithm:
    - For each ^/_:
      1) Slide it left across whitespace/punctuation (free).
      2) If left neighbor ∈ DICHRONA → OK.
      3) Else perform exactly ONE real swap with that left neighbor.
      4) Then slide left across whitespace/punctuation again (free).
      5) If left neighbor ∈ DICHRONA → OK, else raise ValueError.
    """
    chars = list(string)
    i = 0
    n = len(chars)

    while i < n:
        if chars[i] in {"^", "_"}:
            # Free slide left first
            i = _slide_left_over_punct(chars, i)

            if i == 0:
                print(f"Markup error: diacritic at start in: {string!r}")

            if chars[i - 1] not in DICHRONA:
                # One real swap with the immediate (non-punct) neighbor
                chars[i], chars[i - 1] = chars[i - 1], chars[i]
                i -= 1  # diacritic moved one left

                # Free slide again after the real swap
                i = _slide_left_over_punct(chars, i)

                if i == 0 or chars[i - 1] not in DICHRONA:
                    print(f"Invalid markup: diacritic not after DICHRONA near index {i} in {string!r}")
                    return string
            # continue scanning; i now points to the diacritic's position
        i += 1

    return "".join(chars)

print(markup_after_dichrona("πατρί Κ^νοσσός"))
print(markup_after_dichrona("κα^τὰ Χ^ρι_στι^α_νῶν"))
print(markup_after_dichrona("ἄτρ^απος"))
# Out:
# πατρί^ Κνοσσός
# κα^τὰ^ Χρι_στι^α_νῶν
# Invalid markup: diacritic not after DICHRONA near index 2 in 'ἄτρ^απος'
# ἄτρ^απος

# %%
import os
from tqdm import tqdm

directory = "norma_macronizer_mini"

files = [f for f in os.listdir(directory) if f.endswith(".txt")]

for f in tqdm(files):
    path = os.path.join(directory, f)

    with open(path, "r", encoding="utf-8") as input_file:
        lines = [markup_after_dichrona(line.strip()) for line in input_file]

    with open(path, "w", encoding="utf-8") as output_file:
        output_file.write("\n".join(lines))
# Out:
# 100%|██████████| 15/15 [00:00<00:00, 953.41it/s]
# Invalid markup: diacritic not after DICHRONA near index 20 in 'σιδήρῳκαὶἀ^πα^θὴστὸσῶ^μαπ^λασσόμενοσεἶτα^'
# Invalid markup: diacritic not after DICHRONA near index 35 in 'λόγῳὅσα^ἡμέτερα^ἔργα^οὐκἐφἡμῖνδὲτὸσῶ^μα^ἡκτῆσισ^'
# Invalid markup: diacritic not after DICHRONA near index 6 in 'πᾶντὸσῶ^μα^κἀ^ποσείσασθαιτὸγῆρασ^τόδε'
# Invalid markup: diacritic not after DICHRONA near index 4 in 'ἱ^ερᾶ_σὑ^πὸτι_μῆσ'
# Invalid markup: diacritic not after DICHRONA near index 24 in 'φρίκ^σασ_δαὐτοκόμουλοφιᾶσ_λα^σιαύχενα^χαίταν'
# Invalid markup: diacritic not after DICHRONA near index 23 in 'ἡμεῖσδέγαὖδσητήσομενθρετ^τα^νελοτὸνκύκλωπα^'
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %% [markdown]
# Add Eric's preprocessing of diphthongs and final sigmas. Should also ignore longs in closed sylls!

# %%
# === 2. Diphthong component sets ===
diphth_y = {'α', 'ε', 'η', 'ο'}
upsilon_forms = {'ὐ','ὔ','υ','ὑ','ύ','ὖ','ῦ','ὕ','ὗ','ὺ','ὒ','ὓ'}

diphth_i = {'α', 'ε', 'ο', 'υ'}
iota_forms = {'ἰ','ί','ι','ῖ','ἴ','ἶ','ἵ','ἱ','ἷ','ὶ','ἲ','ἳ'}

# Iota subscript/adscript combinations
adscr_i_first = {
    'α','η','ω','ἀ','ἠ','ὠ','ἁ','ἡ','ὡ','ά','ή','ώ','ὰ','ὴ','ὼ',
    'ᾶ','ῆ','ῶ','ὤ','ὥ','ὢ','ὣ','ἄ','ἅ','ἂ','ἃ','ἤ','ἥ','ἣ',
    'ἢ','ἦ','ἧ','ἆ','ἇ','ὧ','ὦ'
}
adscr_i_second = {'ι'}

# === 3. Word processor: expansion and diphthong merging ===

def process_word(word):
    """
    Expand special Greek letters and merge diphthongs.

    Args:
        word (str): A lowercase Greek word.

    Returns:
        list of str: A list of tokens (letters or diphthongs).
    """
    expanded = []

    # Step 1: Expand characters like ζ → δσ, ξ → κσ, etc.
    for char in word:
        if char == 'ζ':
            expanded.extend(['δ', 'σ'])
        elif char == 'ς':
            expanded.append('σ')
        elif char == 'ῥ':
            expanded.append('ρ')
        elif char == 'ξ':
            expanded.extend(['κ', 'σ'])
        elif char == 'ψ':
            expanded.extend(['π', 'σ'])
        else:
            expanded.append(char)

    # Step 2: Merge diphthongs and adscript combinations
    combined = []
    i = 0
    while i < len(expanded):
        a = expanded[i]
        b = expanded[i+1] if i + 1 < len(expanded) else ''

        if a in diphth_y and b in upsilon_forms:
            combined.append(a + b)
            i += 2
        elif a in diphth_i and b in iota_forms:
            combined.append(a + b)
            i += 2
        elif a in adscr_i_first and b in adscr_i_second:
            combined.append(a + b)
            i += 2
        else:
            combined.append(a)
            i += 1

    return combined

# %% [markdown]
# First we let it default to short like the algo macronizer:

# %%
import os
from grc_utils import lower_grc, normalize_word, VOWELS, CONSONANTS

greek_chars = VOWELS | CONSONANTS

macronizer_versions = "norma_macronizer_mini"
gold_versions = "norma-syllabarum-graecarum/final"

# global counters
short_total_global = 0
long_total_global = 0
short_fails_global = 0
long_fails_global = 0
line_total_global = 0
line_matches_global = 0

def clean_line(line):
    line = line.strip()
    line = lower_grc(line)
    line = normalize_word(line)

    remove = set(line) - greek_chars - set("^_")
    table = str.maketrans("", "", "".join(remove))
    line = line.translate(table)
    
    line = "".join(process_word(line))
    return line

def strip_markers(s):
    """Remove ^ and _ for comparison of base text."""
    return s.replace("^", "").replace("_", "")

# iterate over all files in gold folder
for fname in os.listdir(gold_versions):
    if not fname.endswith(".txt"):
        continue

    gold_path = os.path.join(gold_versions, fname)
    macronizer_path = os.path.join(macronizer_versions, fname)

    if not os.path.exists(macronizer_path):
        print(f"Skipping {fname}: no matching macronizer file.")
        continue

    with open(gold_path, encoding="utf-8") as g, open(macronizer_path, encoding="utf-8") as m:
        gold_lines = [clean_line(l) for l in g if l.strip()]
        macronizer_lines = [clean_line(l) for l in m if l.strip()]

    # per-file counters
    short_total = 0
    long_total = 0
    short_fails = 0
    long_fails = 0
    line_total = 0
    line_matches = 0

    # safeguard: iterate over min length
    for gold_line, macron_line in zip(gold_lines, macronizer_lines):
        gi = len(gold_line) - 1
        mi = len(macron_line) - 1

        # line-level match ignoring ^_
        line_total += 1
        if strip_markers(gold_line) == strip_markers(macron_line):
            line_matches += 1
        else:
            print(strip_markers(gold_line) + "\n≠\n" + strip_markers(macron_line) + "\n")

        while gi >= 0:
            gch = gold_line[gi]

            if gch == "^":
                short_total += 1
                if mi < 0 or macron_line[mi] != "^":
                    short_fails += 1
                    print(f"Gold:     {gold_line}")
                    print(f"Macronizer: {macron_line}")
                else:
                    mi -= 1  # matched short

            elif gch == "_":
                long_total += 1
                if mi < 0 or macron_line[mi] != "_":
                    long_fails += 1
                    print(f"Gold:     {gold_line}")
                    print(f"Macronizer: {macron_line}")
                else:
                    mi -= 1  # matched long

            else:
                mi -= 1  # advance only on real characters

            gi -= 1

    # update globals
    short_total_global += short_total
    long_total_global += long_total
    short_fails_global += short_fails
    long_fails_global += long_fails
    line_total_global += line_total
    line_matches_global += line_matches

    # per-file report
    short_success = short_total - short_fails
    long_success = long_total - long_fails
    both_total = short_total + long_total
    both_success = short_success + long_success

    print(f"\n=== File: {fname} ===")
    if short_total:
        print(f"^ success: {short_success}/{short_total} = {short_success/short_total:.4f}")
    if long_total:
        print(f"_ success: {long_success}/{long_total} = {long_success/long_total:.4f}")
    if both_total:
        print(f"Both success: {both_success}/{both_total} = {both_success/both_total:.4f}")
    if line_total:
        print(f"Line matches ignoring ^_: {line_matches}/{line_total} = {line_matches/line_total:.4f}")

# global summary
short_success_global = short_total_global - short_fails_global
long_success_global = long_total_global - long_fails_global
both_total_global = short_total_global + long_total_global
both_success_global = short_success_global + long_success_global

print("\n=== Global summary ===")
if short_total_global:
    print(f"^ success: {short_success_global}/{short_total_global} = {short_success_global/short_total_global:.4f}")
if long_total_global:
    print(f"_ success: {long_success_global}/{long_total_global} = {long_success_global/long_total_global:.4f}")
if both_total_global:
    print(f"Both success: {both_success_global}/{both_total_global} = {both_success_global/both_total_global:.4f}")
if line_total_global:
    print(f"Line matches ignoring ^_: {line_matches_global}/{line_total_global} = {line_matches_global/line_total_global:.4f}")
# Out:
# Gold:     ὁμὲνσωτὴρκαὶκύ_ρι^οσἡμῶνἰ_ησοῦσχριστὸσ
# Macronizer: ὁμὲνσωτὴρκαὶκύ_ρι^οσἡμῶνἰ^ησοῦσχριστὸσ
# Gold:     ὁμὲνσωτὴρκαὶκύ_ρι^οσἡμῶνἰ_ησοῦσχριστὸσ
# Macronizer: ὁμὲνσωτὴρκαὶκύ_ρι^οσἡμῶνἰ^ησοῦσχριστὸσ
# Gold:     ὁμὲνσωτὴρκαὶκύ_ρι^οσἡμῶνἰ_ησοῦσχριστὸσ
# Macronizer: ὁμὲνσωτὴρκαὶκύ_ρι^οσἡμῶνἰ^ησοῦσχριστὸσ
# Gold:     καὶτὰ_σἐνἰ_ουδαίοισπράκσεισκρείττουσγεγονέναιφωνῆσ
# Macronizer: καὶτὰ_σἐνἰ^ουδαίοισπράκσεισκρείττουσγεγονέναιφωνῆσ
# Gold:     καὶτὰ_σἐνἰ_ουδαίοισπράκσεισκρείττουσγεγονέναιφωνῆσ
# Macronizer: καὶτὰ_σἐνἰ^ουδαίοισπράκσεισκρείττουσγεγονέναιφωνῆσ
# Gold:     ἐλεγχούσηστὴνπσευδομαρτυ^ρί^α_νκαὶλέκσεωνἀ^πολογουμένων
# Macronizer: ἐλεγχούσηστὴνπσευδομαρτυ^ρί^ανκαὶλέκσεωνἀ^πολογουμένων
# Gold:     οἶδὅπωσπρὸστὰ_σκέλσουκα^τὰ^χρι_στι^α_νῶνἐνσυγγράμμα^σι^
# Macronizer: οἶδὅπωσπρὸστὰ_σκέλσουκα^τὰ^χριστια_νῶνἐνσυγγράμμα^σι^
# Gold:     οἶδὅπωσπρὸστὰ_σκέλσουκα^τὰ^χρι_στι^α_νῶνἐνσυγγράμμα^σι^
# Macronizer: οἶδὅπωσπρὸστὰ_σκέλσουκα^τὰ^χριστια_νῶνἐνσυγγράμμα^σι^
# Gold:     πσευδομαρτυ^ρί^α_σκαὶτῆσπίστεωστῶνἐκκλησι^ῶνἐνβιβλί^ῳ
# Macronizer: πσευδομαρτυ^ρί^α_σκαὶτῆσπίστεωστῶνἐκκλησι^ῶνἐνβι^βλί^ῳ
# Gold:     πσευδομαρτυ^ρί^α_σκαὶτῆσπίστεωστῶνἐκκλησι^ῶνἐνβιβλί^ῳ
# Macronizer: πσευδομαρτυ^ρί^α_σκαὶτῆσπίστεωστῶνἐκκλησι^ῶνἐνβι^βλί^ῳ
# Gold:     πσευδομαρτυ^ρί^α_σκαὶτῆσπίστεωστῶνἐκκλησι^ῶνἐνβιβλί^ῳ
# Macronizer: πσευδομαρτυ^ρί^α_σκαὶτῆσπίστεωστῶνἐκκλησι^ῶνἐνβι^βλί^ῳ
# Gold:     πσευδομαρτυ^ρί^α_σκαὶτῆσπίστεωστῶνἐκκλησι^ῶνἐνβιβλί^ῳ
# Macronizer: πσευδομαρτυ^ρί^α_σκαὶτῆσπίστεωστῶνἐκκλησι^ῶνἐνβι^βλί^ῳ
# Gold:     καὶταῖσκα^τηγορί^αισμηδὲπι^θα^νότητα^εἰστὸδύ^να^σθαίτι^
# Macronizer: καὶταῖσκα^τηγορί^αισμηδὲπιθα^νότητα^εἰστὸδύ^να^σθαίτι^
# Gold:     αὐτὰ_σἐνδιδόντοσπερὶ^δὲτοῦἰησοῦὅτι^ἐσι^ώπα_
# Macronizer: αὐτὰ_σἐνδιδόντοσπερὶ^δὲτοῦἰ^ησοῦὅτι^ἐσι^ώπα_
# Gold:     αὐτὰ_σἐνδιδόντοσπερὶ^δὲτοῦἰησοῦὅτι^ἐσι^ώπα_
# Macronizer: αὐτὰ_σἐνδιδόντοσπερὶ^δὲτοῦἰ^ησοῦὅτι^ἐσι^ώπα_
# Gold:     πα^ρα^θέσθαιτὰ^γὰ^ρἰ_σοδυ^να^μοῦντα^αὐτῷὁμάρκοσἔγραπσεν
# Macronizer: πα^ρα^θέσθαιτὰ^γὰ^ρἰ^σοδυ^να^μοῦντα^αὐτῷὁμάρκοσἔγραπσεν
# Gold:     πα^ρα^θέσθαιτὰ^γὰ^ρἰ_σοδυ^να^μοῦντα^αὐτῷὁμάρκοσἔγραπσεν
# Macronizer: πα^ρα^θέσθαιτὰ^γὰ^ρἰ^σοδυ^να^μοῦντα^αὐτῷὁμάρκοσἔγραπσεν
# Gold:     πα^ρα^θέσθαιτὰ^γὰ^ρἰ_σοδυ^να^μοῦντα^αὐτῷὁμάρκοσἔγραπσεν
# Macronizer: πα^ρα^θέσθαιτὰ^γὰ^ρἰ^σοδυ^να^μοῦντα^αὐτῷὁμάρκοσἔγραπσεν
# Gold:     πα^ρα^θέσθαιτὰ^γὰ^ρἰ_σοδυ^να^μοῦντα^αὐτῷὁμάρκοσἔγραπσεν
# Macronizer: πα^ρα^θέσθαιτὰ^γὰ^ρἰ^σοδυ^να^μοῦντα^αὐτῷὁμάρκοσἔγραπσεν
# Gold:     πα^ρα^θέσθαιτὰ^γὰ^ρἰ_σοδυ^να^μοῦντα^αὐτῷὁμάρκοσἔγραπσεν
# Macronizer: πα^ρα^θέσθαιτὰ^γὰ^ρἰ^σοδυ^να^μοῦντα^αὐτῷὁμάρκοσἔγραπσεν
# Gold:     ἔχειδοὕτωσἡτοῦματθαίουλέκσι^σὁδὲἀρχι^ερεὺσ
# Macronizer: ἔχειδοὕτωσἡτοῦματθαίουλέκσι^σὁδὲἀρχιερεὺσ
# Gold:     καὶτὸσυ^νέδρι^ονἐδσήτουνπσευδομαρτυ^ρί^α_νκα^τὰ^τοῦἰησοῦ
# Macronizer: καὶτὸσυ^νέδριονἐδσήτουνπσευδομαρτυ^ρί^ανκα^τὰ^τοῦἰ^ησοῦ
# Gold:     καὶτὸσυ^νέδρι^ονἐδσήτουνπσευδομαρτυ^ρί^α_νκα^τὰ^τοῦἰησοῦ
# Macronizer: καὶτὸσυ^νέδριονἐδσήτουνπσευδομαρτυ^ρί^ανκα^τὰ^τοῦἰ^ησοῦ
# Gold:     καὶτὸσυ^νέδρι^ονἐδσήτουνπσευδομαρτυ^ρί^α_νκα^τὰ^τοῦἰησοῦ
# Macronizer: καὶτὸσυ^νέδριονἐδσήτουνπσευδομαρτυ^ρί^ανκα^τὰ^τοῦἰ^ησοῦ
# Gold:     καὶτὸσυ^νέδρι^ονἐδσήτουνπσευδομαρτυ^ρί^α_νκα^τὰ^τοῦἰησοῦ
# Macronizer: καὶτὸσυ^νέδριονἐδσήτουνπσευδομαρτυ^ρί^ανκα^τὰ^τοῦἰ^ησοῦ
# Gold:     καὶτὸσυ^νέδρι^ονἐδσήτουνπσευδομαρτυ^ρί^α_νκα^τὰ^τοῦἰησοῦ
# Macronizer: καὶτὸσυ^νέδριονἐδσήτουνπσευδομαρτυ^ρί^ανκα^τὰ^τοῦἰ^ησοῦ
# Gold:     καὶτὸσυ^νέδρι^ονἐδσήτουνπσευδομαρτυ^ρί^α_νκα^τὰ^τοῦἰησοῦ
# Macronizer: καὶτὸσυ^νέδριονἐδσήτουνπσευδομαρτυ^ρί^ανκα^τὰ^τοῦἰ^ησοῦ
# Gold:     καὶτὸσυ^νέδρι^ονἐδσήτουνπσευδομαρτυ^ρί^α_νκα^τὰ^τοῦἰησοῦ
# Macronizer: καὶτὸσυ^νέδριονἐδσήτουνπσευδομαρτυ^ρί^ανκα^τὰ^τοῦἰ^ησοῦ
#
# === File: contracelsum.txt ===
# ^ success: 57/75 = 0.7600
# _ success: 12/22 = 0.5455
# Both success: 69/97 = 0.7113
# Line matches ignoring ^_: 20/20 = 1.0000
# Gold:     ὁπινδά^ρουκαινεὺσεὔθυ_να^νὑ^πεῖχενἀ^πι^θά^νωσἄρρηκτοσ
# Macronizer: ὁπινδά^ρουκαινεὺσεὔθυ_να^νὑ^πεῖχενἀ^πιθά^νωσἄρρηκτοσ
# Gold:     σι^δήρῳκαὶἀ^πα^θὴστὸσῶμα^πλασσόμενοσεἶτα^
# Macronizer: σιδήρῳκαὶἀ^πα^θὴστὸσῶ^μαπ^λασσόμενοσεἶτα^
# Gold:     σι^δήρῳκαὶἀ^πα^θὴστὸσῶμα^πλασσόμενοσεἶτα^
# Macronizer: σιδήρῳκαὶἀ^πα^θὴστὸσῶ^μαπ^λασσόμενοσεἶτα^
# Gold:     σι^δήρῳκαὶἀ^πα^θὴστὸσῶμα^πλασσόμενοσεἶτα^
# Macronizer: σιδήρῳκαὶἀ^πα^θὴστὸσῶ^μαπ^λασσόμενοσεἶτα^
# Gold:     κα^τα^δὺ_σἄτρωτοσὑ^πὸγῆνσχί^σα^σὀρθῷποδὶ^γᾶν
# Macronizer: κα^τα^δὺ_σἄτρωτοσὑ^πὸγῆνσχί^σα_σὀρθῷποδὶ^γᾶν
# Gold:     κα^τα^δὺ_σἄτρωτοσὑ^πὸγῆνσχί^σα^σὀρθῷποδὶ^γᾶν
# Macronizer: κα^τα^δὺ_σἄτρωτοσὑ^πὸγῆνσχί^σα_σὀρθῷποδὶ^γᾶν
# Gold:     κα^τα^δὺ_σἄτρωτοσὑ^πὸγῆνσχί^σα^σὀρθῷποδὶ^γᾶν
# Macronizer: κα^τα^δὺ_σἄτρωτοσὑ^πὸγῆνσχί^σα_σὀρθῷποδὶ^γᾶν
# Gold:     κα^τα^δὺ_σἄτρωτοσὑ^πὸγῆνσχί^σα^σὀρθῷποδὶ^γᾶν
# Macronizer: κα^τα^δὺ_σἄτρωτοσὑ^πὸγῆνσχί^σα_σὀρθῷποδὶ^γᾶν
# Gold:     κα^τα^δὺ_σἄτρωτοσὑ^πὸγῆνσχί^σα^σὀρθῷποδὶ^γᾶν
# Macronizer: κα^τα^δὺ_σἄτρωτοσὑ^πὸγῆνσχί^σα_σὀρθῷποδὶ^γᾶν
# Gold:     κα^τα^δὺ_σἄτρωτοσὑ^πὸγῆνσχί^σα^σὀρθῷποδὶ^γᾶν
# Macronizer: κα^τα^δὺ_σἄτρωτοσὑ^πὸγῆνσχί^σα_σὀρθῷποδὶ^γᾶν
# Gold:     πα^λαίεινἀ^ήττητόσἐστι^καὶπερι^τειχι^δσόμενοσἀ^πολι^όρκητοσ
# Macronizer: πα^λαίεινἀ^ήττητόσἐστι^καὶπερι^τειχι^δσόμενοσἀ^πολιόρκητοσ
# Gold:     καὶπωλούμενοσὑ^πὸτῶνπολεμί^ωνἀ^νά^λωτοσοὐθὲν
# Macronizer: καὶπωλούμενοσὑ^πὸτῶνπολεμί^ωνἀ^νά_λωτοσοὐθὲν
# Gold:     καὶπωλούμενοσὑ^πὸτῶνπολεμί^ωνἀ^νά^λωτοσοὐθὲν
# Macronizer: καὶπωλούμενοσὑ^πὸτῶνπολεμί^ωνἀ^νά_λωτοσοὐθὲν
# Gold:     καὶπωλούμενοσὑ^πὸτῶνπολεμί^ωνἀ^νά^λωτοσοὐθὲν
# Macronizer: καὶπωλούμενοσὑ^πὸτῶνπολεμί^ωνἀ^νά_λωτοσοὐθὲν
# Gold:     καὶπωλούμενοσὑ^πὸτῶνπολεμί^ωνἀ^νά^λωτοσοὐθὲν
# Macronizer: καὶπωλούμενοσὑ^πὸτῶνπολεμί^ωνἀ^νά_λωτοσοὐθὲν
# Gold:     ὁεὐρι_πί^δουἰ^όλα_οσἐκσἀ^δρα^νοῦσκαὶπα^ρήλι^κοσεὐχῇ
# Macronizer: ὁεὐριπί^δουἰ^όλα_οσἐκσἀδρα^νοῦσκαὶπα^ρήλι^κοσεὐχῇ
# Gold:     ὁεὐρι_πί^δουἰ^όλα_οσἐκσἀ^δρα^νοῦσκαὶπα^ρήλι^κοσεὐχῇ
# Macronizer: ὁεὐριπί^δουἰ^όλα_οσἐκσἀδρα^νοῦσκαὶπα^ρήλι^κοσεὐχῇ
# Gold:     τι^νι^νέοσκαὶἰσχυ_ρὸσἐπὶ^τὴνμά^χηνἄ^φνωγέγονεν
# Macronizer: τι^νι^νέοσκαὶἰσχυ_ρὸσἐπὶ^τὴνμά^χηνἄφνωγέγονεν
# Gold:     ἅ^μα^καὶκά^κι^στοστήμερονδἄ^φνωμετα^βέβληκενεἰσ
# Macronizer: ἅ^μα^καὶκά^κι^στοστήμερονδἄφνωμετα^βέβληκενεἰσ
# Gold:     ἀ^ρετὴνκαὶγέγονενἐκρυ_σοῦκαὶὠχροῦκαὶκα^ταἰσχύ^λον
# Macronizer: ἀ^ρετὴνκαὶγέγονενἐκρυ_σοῦκαὶὠχροῦκαὶκα^τα^ἰσχύ^λον
# Gold:     ἀ^ρετὴνκαὶγέγονενἐκρυ_σοῦκαὶὠχροῦκαὶκα^ταἰσχύ^λον
# Macronizer: ἀ^ρετὴνκαὶγέγονενἐκρυ_σοῦκαὶὠχροῦκαὶκα^τα^ἰσχύ^λον
# Gold:     ἀ^ρετὴνκαὶγέγονενἐκρυ_σοῦκαὶὠχροῦκαὶκα^ταἰσχύ^λον
# Macronizer: ἀ^ρετὴνκαὶγέγονενἐκρυ_σοῦκαὶὠχροῦκαὶκα^τα^ἰσχύ^λον
# Gold:     ἐκσὀσφυ^αλγοῦσκαὶὀδυ^νοσπά^δοσλυ^γροῦγέροντοσ
# Macronizer: ἐκσὀσφυ^αλγοῦσκαὶὀδυ^νοσπά^δοσλυγροῦγέροντοσ
#
# === File: plutarchus.txt ===
# ^ success: 75/95 = 0.7895
# _ success: 9/12 = 0.7500
# Both success: 84/107 = 0.7850
# Line matches ignoring ^_: 24/24 = 1.0000
# Gold:     δσεὺσμὲνἀ^φίκτωρἐπί^δοιπροφρόνωσστόλονἡμέτεροννάιονἀρθέντἀ^πὸπροστομί^ωνλεπτοπσα^μά^θωννείλουδί_α_νδὲλι^ποῦσαι
# Macronizer: δσεὺσμὲνἀ^φίκτωρἐπί^δοιπροφρόνωσστόλονἡμέτεροννά^ιονἀρθέντἀ^πὸπροστομί^ωνλεπτοπσα^μά^θωννείλουδί_ανδὲλι^ποῦσαι
# Gold:     δσεὺσμὲνἀ^φίκτωρἐπί^δοιπροφρόνωσστόλονἡμέτεροννάιονἀρθέντἀ^πὸπροστομί^ωνλεπτοπσα^μά^θωννείλουδί_α_νδὲλι^ποῦσαι
# Macronizer: δσεὺσμὲνἀ^φίκτωρἐπί^δοιπροφρόνωσστόλονἡμέτεροννά^ιονἀρθέντἀ^πὸπροστομί^ωνλεπτοπσα^μά^θωννείλουδί_ανδὲλι^ποῦσαι
# Gold:     δσεὺσμὲνἀ^φίκτωρἐπί^δοιπροφρόνωσστόλονἡμέτεροννάιονἀρθέντἀ^πὸπροστομί^ωνλεπτοπσα^μά^θωννείλουδί_α_νδὲλι^ποῦσαι
# Macronizer: δσεὺσμὲνἀ^φίκτωρἐπί^δοιπροφρόνωσστόλονἡμέτεροννά^ιονἀρθέντἀ^πὸπροστομί^ωνλεπτοπσα^μά^θωννείλουδί_ανδὲλι^ποῦσαι
# Gold:     χθόνα^σύγχορτονσυ^ρί^ᾳφεύγομενοὔτι^νἐφαἵμα^τι^δημηλα^σί^ανπσήφῳπόλεωσγνωσθεῖσαι
# Macronizer: χθόνα^σύγχορτονσυ^ρί^ᾳφεύγομενοὔτινἐφαἵμα^τι^δημηλα^σί^ανπσήφῳπόλεωσγνωσθεῖσαι
# Gold:     ἀλλαὐτογενεῖφυκσα_νορί^ανγά^μοναἰγύπτουπαίδωνἀ^σεβῆτὀνοταδσόμεναιδι^ά^νοια^ν
# Macronizer: ἀλλαὐτογενεῖφυκσα^νορί^ανγά^μοναἰγύπτουπαίδωνἀ^σεβῆτὀνοταδσόμεναιδι^ά^νοια^ν
#
# === File: supplices.txt ===
# ^ success: 18/21 = 0.8571
# _ success: 1/3 = 0.3333
# Both success: 19/24 = 0.7917
# Line matches ignoring ^_: 3/3 = 1.0000
# Gold:     εἰπέθεά_κρονί^δα_οδι^άκτοροναἴθοποσαὐγῆσ
# Macronizer: εἰπέθεάκρονί^δα^οδιάκτοροναἴθοποσαὐγῆσ
# Gold:     εἰπέθεά_κρονί^δα_οδι^άκτοροναἴθοποσαὐγῆσ
# Macronizer: εἰπέθεάκρονί^δα^οδιάκτοροναἴθοποσαὐγῆσ
# Gold:     εἰπέθεά_κρονί^δα_οδι^άκτοροναἴθοποσαὐγῆσ
# Macronizer: εἰπέθεάκρονί^δα^οδιάκτοροναἴθοποσαὐγῆσ
# Gold:     εἰπέθεά_κρονί^δα_οδι^άκτοροναἴθοποσαὐγῆσ
# Macronizer: εἰπέθεάκρονί^δα^οδιάκτοροναἴθοποσαὐγῆσ
# Gold:     νυμφι^δί^ῳσπινθῆρι^μογοστόκονἆσθμα^κεραυνοῦ
# Macronizer: νυμφιδί^ῳσπινθῆρι^μογοστόκονἆσθμα^κεραυνοῦ
# Gold:     βάκχουδισσοτόκοιοτὸνἐκπυ^ρὸσὑγρὸνἀ^είρα_σ
# Macronizer: βάκχουδισσοτόκοιοτὸνἐκπυ_ρὸσὑγρὸνἀ^είρα_σ
# Gold:     δσεὺσβρέφοσἡμι^τέλεστονἀ^μαιεύτοιοτεκούσησ
# Macronizer: δσεὺσβρέφοσἡμιτέλεστονἀ^μαιεύτοιοτεκούσησ
# Gold:     ἄ^ρσενι^γαστρὶ^λόχευσεπα^τὴρκαὶπότνι^α^μήτηρ
# Macronizer: ἄ^ρσενι^γαστρὶ^λόχευσεπα^τὴρκαὶπότνια^μήτηρ
# Gold:     ἄσπορονὄγκονἄ^πι^στονἔχωνἐγκύ_μονι^κόρσῃ
# Macronizer: ἄσπορονὄγκονἄ^πι^στονἔχωνἐγκύ^μονι^κόρσῃ
# Gold:     ἄσπορονὄγκονἄ^πι^στονἔχωνἐγκύ_μονι^κόρσῃ
# Macronizer: ἄσπορονὄγκονἄ^πι^στονἔχωνἐγκύ^μονι^κόρσῃ
# Gold:     ἄσπορονὄγκονἄ^πι^στονἔχωνἐγκύ_μονι^κόρσῃ
# Macronizer: ἄσπορονὄγκονἄ^πι^στονἔχωνἐγκύ^μονι^κόρσῃ
# Gold:     ἄ^κσα^τέμοινάρθηκα^τι^νάκσα^τεκύ^μβα^λα^μοῦσαι
# Macronizer: ἄ^κσα^τέμοινάρθηκα^τινάκσα^τεκύ^μβα^λα^μοῦσαι
# Gold:     καὶπα^λά^μῃδότεθύρσονἀ^ειδομένουδι^ονύ_σου
# Macronizer: καὶπα^λά^μῃδότεθύρσονἀ^ειδομένουδιονύ^σου
# Gold:     καὶπα^λά^μῃδότεθύρσονἀ^ειδομένουδι^ονύ_σου
# Macronizer: καὶπα^λά^μῃδότεθύρσονἀ^ειδομένουδιονύ^σου
# Gold:     καὶπα^λά^μῃδότεθύρσονἀ^ειδομένουδι^ονύ_σου
# Macronizer: καὶπα^λά^μῃδότεθύρσονἀ^ειδομένουδιονύ^σου
# Gold:     καὶπα^λά^μῃδότεθύρσονἀ^ειδομένουδι^ονύ_σου
# Macronizer: καὶπα^λά^μῃδότεθύρσονἀ^ειδομένουδιονύ^σου
# Gold:     φρικτὰ^δρα^κοντοκόμωνἐδα^ΐ^δσετοφῦλα^γι^γά^ντων
# Macronizer: φρικτὰ^δρα^κοντοκόμωνἐδα^ΐ^δσετοφῦλα^γιγάντων
# Gold:     φρικτὰ^δρα^κοντοκόμωνἐδα^ΐ^δσετοφῦλα^γι^γά^ντων
# Macronizer: φρικτὰ^δρα^κοντοκόμωνἐδα^ΐ^δσετοφῦλα^γιγάντων
#
# === File: dionysiaca.txt ===
# ^ success: 63/77 = 0.8182
# _ success: 2/6 = 0.3333
# Both success: 65/83 = 0.7831
# Line matches ignoring ^_: 20/20 = 1.0000
# Gold:     κρα^τύ_λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ^ντι^νεσσυ^νθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπι^φθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Macronizer: κρα^τύ^λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ_ντι^νεσσυνθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπιφθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Gold:     κρα^τύ_λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ^ντι^νεσσυ^νθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπι^φθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Macronizer: κρα^τύ^λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ_ντι^νεσσυνθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπιφθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Gold:     κρα^τύ_λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ^ντι^νεσσυ^νθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπι^φθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Macronizer: κρα^τύ^λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ_ντι^νεσσυνθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπιφθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Gold:     κρα^τύ_λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ^ντι^νεσσυ^νθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπι^φθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Macronizer: κρα^τύ^λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ_ντι^νεσσυνθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπιφθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Gold:     κρα^τύ_λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ^ντι^νεσσυ^νθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπι^φθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Macronizer: κρα^τύ^λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ_ντι^νεσσυνθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπιφθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Gold:     κρα^τύ_λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ^ντι^νεσσυ^νθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπι^φθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Macronizer: κρα^τύ^λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ_ντι^νεσσυνθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπιφθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Gold:     κρα^τύ_λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ^ντι^νεσσυ^νθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπι^φθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Macronizer: κρα^τύ^λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ_ντι^νεσσυνθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπιφθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Gold:     κρα^τύ_λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ^ντι^νεσσυ^νθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπι^φθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Macronizer: κρα^τύ^λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ_ντι^νεσσυνθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπιφθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Gold:     κρα^τύ_λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ^ντι^νεσσυ^νθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπι^φθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Macronizer: κρα^τύ^λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ_ντι^νεσσυνθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπιφθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Gold:     κρα^τύ_λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ^ντι^νεσσυ^νθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπι^φθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Macronizer: κρα^τύ^λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ_ντι^νεσσυνθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπιφθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Gold:     κρα^τύ_λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ^ντι^νεσσυ^νθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπι^φθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Macronizer: κρα^τύ^λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ_ντι^νεσσυνθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπιφθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Gold:     κρα^τύ_λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ^ντι^νεσσυ^νθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπι^φθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Macronizer: κρα^τύ^λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ_ντι^νεσσυνθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπιφθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Gold:     κρα^τύ_λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ^ντι^νεσσυ^νθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπι^φθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Macronizer: κρα^τύ^λοσφησὶ^νὅδεὦσώκρα^τεσὀνόμα^τοσὀρθότητα^εἶναιἑκάστῳτῶνὄντωνφύ^σειπεφυ_κυῖα^νκαὶοὐτοῦτοεἶναιὄνομα^ὃἄ_ντι^νεσσυνθέμενοικα^λεῖνκα^λῶσι^τῆσαὑτῶνφωνῆσμόρι^ονἐπιφθεγγόμενοιἀλλὰ^ὀρθότητά^τι^να^τῶνὀνομά^τωνπεφυ_κέναικαὶἕλλησι^καὶβα^ρβά^ροιστὴναὐτὴνἅ^πα_σι^ν
# Gold:     ἐρωτῶοὖναὐτὸνἐγὼεἰαὐτῷκρα^τύ_λοστῇἀ^ληθείᾳὄνομα^ἐστὶ^νἢοὔὁδὲὁμολογεῖ
# Macronizer: ἐρωτῶοὖναὐτὸνἐγὼεἰαὐτῷκρα^τύ^λοστῇἀ^ληθείᾳὄνομα^ἐστὶ^νἢοὔὁδὲὁμολογεῖ
# Gold:     ἐρωτῶοὖναὐτὸνἐγὼεἰαὐτῷκρα^τύ_λοστῇἀ^ληθείᾳὄνομα^ἐστὶ^νἢοὔὁδὲὁμολογεῖ
# Macronizer: ἐρωτῶοὖναὐτὸνἐγὼεἰαὐτῷκρα^τύ^λοστῇἀ^ληθείᾳὄνομα^ἐστὶ^νἢοὔὁδὲὁμολογεῖ
# Gold:     οὐκοῦνκαὶτοῖσἄλλοισἀνθρώποισπᾶσι^νὅπερκα^λοῦμενὄνομα^ἕκαστοντοῦτόἐστι^νἑκάστῳὄνομα^ὁδέοὔκουνσοίγεἦδὅσὄνομα^ἑρμογένησοὐδὲἂ^νπάντεσκα^λῶσι^νἄνθρωποι
# Macronizer: οὐκοῦνκαὶτοῖσἄλλοισἀνθρώποισπᾶσι^νὅπερκα^λοῦμενὄνομα^ἕκαστοντοῦτόἐστι^νἑκάστῳὄνομα^ὁδέοὔ^κουνσοίγεἦδὅσὄνομα^ἑρμογένησοὐδὲἂ_νπάντεσκα^λῶσι^νἄνθρωποι
# Gold:     οὐκοῦνκαὶτοῖσἄλλοισἀνθρώποισπᾶσι^νὅπερκα^λοῦμενὄνομα^ἕκαστοντοῦτόἐστι^νἑκάστῳὄνομα^ὁδέοὔκουνσοίγεἦδὅσὄνομα^ἑρμογένησοὐδὲἂ^νπάντεσκα^λῶσι^νἄνθρωποι
# Macronizer: οὐκοῦνκαὶτοῖσἄλλοισἀνθρώποισπᾶσι^νὅπερκα^λοῦμενὄνομα^ἕκαστοντοῦτόἐστι^νἑκάστῳὄνομα^ὁδέοὔ^κουνσοίγεἦδὅσὄνομα^ἑρμογένησοὐδὲἂ_νπάντεσκα^λῶσι^νἄνθρωποι
# Gold:     οὐκοῦνκαὶτοῖσἄλλοισἀνθρώποισπᾶσι^νὅπερκα^λοῦμενὄνομα^ἕκαστοντοῦτόἐστι^νἑκάστῳὄνομα^ὁδέοὔκουνσοίγεἦδὅσὄνομα^ἑρμογένησοὐδὲἂ^νπάντεσκα^λῶσι^νἄνθρωποι
# Macronizer: οὐκοῦνκαὶτοῖσἄλλοισἀνθρώποισπᾶσι^νὅπερκα^λοῦμενὄνομα^ἕκαστοντοῦτόἐστι^νἑκάστῳὄνομα^ὁδέοὔ^κουνσοίγεἦδὅσὄνομα^ἑρμογένησοὐδὲἂ_νπάντεσκα^λῶσι^νἄνθρωποι
# Gold:     οὐκοῦνκαὶτοῖσἄλλοισἀνθρώποισπᾶσι^νὅπερκα^λοῦμενὄνομα^ἕκαστοντοῦτόἐστι^νἑκάστῳὄνομα^ὁδέοὔκουνσοίγεἦδὅσὄνομα^ἑρμογένησοὐδὲἂ^νπάντεσκα^λῶσι^νἄνθρωποι
# Macronizer: οὐκοῦνκαὶτοῖσἄλλοισἀνθρώποισπᾶσι^νὅπερκα^λοῦμενὄνομα^ἕκαστοντοῦτόἐστι^νἑκάστῳὄνομα^ὁδέοὔ^κουνσοίγεἦδὅσὄνομα^ἑρμογένησοὐδὲἂ_νπάντεσκα^λῶσι^νἄνθρωποι
# Gold:     οὐκοῦνκαὶτοῖσἄλλοισἀνθρώποισπᾶσι^νὅπερκα^λοῦμενὄνομα^ἕκαστοντοῦτόἐστι^νἑκάστῳὄνομα^ὁδέοὔκουνσοίγεἦδὅσὄνομα^ἑρμογένησοὐδὲἂ^νπάντεσκα^λῶσι^νἄνθρωποι
# Macronizer: οὐκοῦνκαὶτοῖσἄλλοισἀνθρώποισπᾶσι^νὅπερκα^λοῦμενὄνομα^ἕκαστοντοῦτόἐστι^νἑκάστῳὄνομα^ὁδέοὔ^κουνσοίγεἦδὅσὄνομα^ἑρμογένησοὐδὲἂ_νπάντεσκα^λῶσι^νἄνθρωποι
# Gold:     οὐκοῦνκαὶτοῖσἄλλοισἀνθρώποισπᾶσι^νὅπερκα^λοῦμενὄνομα^ἕκαστοντοῦτόἐστι^νἑκάστῳὄνομα^ὁδέοὔκουνσοίγεἦδὅσὄνομα^ἑρμογένησοὐδὲἂ^νπάντεσκα^λῶσι^νἄνθρωποι
# Macronizer: οὐκοῦνκαὶτοῖσἄλλοισἀνθρώποισπᾶσι^νὅπερκα^λοῦμενὄνομα^ἕκαστοντοῦτόἐστι^νἑκάστῳὄνομα^ὁδέοὔ^κουνσοίγεἦδὅσὄνομα^ἑρμογένησοὐδὲἂ_νπάντεσκα^λῶσι^νἄνθρωποι
# Gold:     οὐκοῦνκαὶτοῖσἄλλοισἀνθρώποισπᾶσι^νὅπερκα^λοῦμενὄνομα^ἕκαστοντοῦτόἐστι^νἑκάστῳὄνομα^ὁδέοὔκουνσοίγεἦδὅσὄνομα^ἑρμογένησοὐδὲἂ^νπάντεσκα^λῶσι^νἄνθρωποι
# Macronizer: οὐκοῦνκαὶτοῖσἄλλοισἀνθρώποισπᾶσι^νὅπερκα^λοῦμενὄνομα^ἕκαστοντοῦτόἐστι^νἑκάστῳὄνομα^ὁδέοὔ^κουνσοίγεἦδὅσὄνομα^ἑρμογένησοὐδὲἂ_νπάντεσκα^λῶσι^νἄνθρωποι
# Gold:     εἰοὖνπῃἔχεισσυ^μβα^λεῖντὴνκρα^τύ_λουμα^ντεία_νἡδέωσἂ^νἀ^κούσαιμι^
# Macronizer: εἰοὖνπῃἔχεισσυ^μβα^λεῖντὴνκρα^τύ^λουμα^ντεία_νἡδέωσἂ^νἀ^κούσαιμι^
# Gold:     εἰοὖνπῃἔχεισσυ^μβα^λεῖντὴνκρα^τύ_λουμα^ντεία_νἡδέωσἂ^νἀ^κούσαιμι^
# Macronizer: εἰοὖνπῃἔχεισσυ^μβα^λεῖντὴνκρα^τύ^λουμα^ντεία_νἡδέωσἂ^νἀ^κούσαιμι^
# Gold:     εἰοὖνπῃἔχεισσυ^μβα^λεῖντὴνκρα^τύ_λουμα^ντεία_νἡδέωσἂ^νἀ^κούσαιμι^
# Macronizer: εἰοὖνπῃἔχεισσυ^μβα^λεῖντὴνκρα^τύ^λουμα^ντεία_νἡδέωσἂ^νἀ^κούσαιμι^
# Gold:     εἰοὖνπῃἔχεισσυ^μβα^λεῖντὴνκρα^τύ_λουμα^ντεία_νἡδέωσἂ^νἀ^κούσαιμι^
# Macronizer: εἰοὖνπῃἔχεισσυ^μβα^λεῖντὴνκρα^τύ^λουμα^ντεία_νἡδέωσἂ^νἀ^κούσαιμι^
#
# === File: cratylus.txt ===
# ^ success: 40/62 = 0.6452
# _ success: 5/9 = 0.5556
# Both success: 45/71 = 0.6338
# Line matches ignoring ^_: 9/9 = 1.0000
# Gold:     δὴτότετρῶεσἔμιμνονἀ^νὰ^πρι^ά^μοιοπόληα^
# Macronizer: δὴτότετρῶεσἔμιμνονἀ^νὰ^πριά^μοιοπόληα^
# Gold:     δειδι^ότεσμένοσἠῢ^θρα^σύφρονοσαἰα^κί^δα_ο
# Macronizer: δειδι^ότεσμένοσἠῢθρα_σύφρονοσαἰα^κί^δα^ο
# Gold:     δειδι^ότεσμένοσἠῢ^θρα^σύφρονοσαἰα^κί^δα_ο
# Macronizer: δειδι^ότεσμένοσἠῢθρα_σύφρονοσαἰα^κί^δα^ο
# Gold:     δειδι^ότεσμένοσἠῢ^θρα^σύφρονοσαἰα^κί^δα_ο
# Macronizer: δειδι^ότεσμένοσἠῢθρα_σύφρονοσαἰα^κί^δα^ο
# Gold:     δειδι^ότεσμένοσἠῢ^θρα^σύφρονοσαἰα^κί^δα_ο
# Macronizer: δειδι^ότεσμένοσἠῢθρα_σύφρονοσαἰα^κί^δα^ο
# Gold:     δειδι^ότεσμένοσἠῢ^θρα^σύφρονοσαἰα^κί^δα_ο
# Macronizer: δειδι^ότεσμένοσἠῢθρα_σύφρονοσαἰα^κί^δα^ο
# Gold:     δειδι^ότεσμένοσἠῢ^θρα^σύφρονοσαἰα^κί^δα_ο
# Macronizer: δειδι^ότεσμένοσἠῢθρα_σύφρονοσαἰα^κί^δα^ο
# Gold:     ἰ_ληδὸνπτώσσουσαιἀ^νὰ^ρωπήι^α^πυκνά^
# Macronizer: ἰ_ληδὸνπτώσσουσαιἀ^νὰ^ρωπήια^πυκνά^
# Gold:     ὥσοἱἀ^νὰ^πτολί^εθρονὑ^πέτρεσα^νὄβρι^μουἄ^νδρα^
# Macronizer: ὥσοἱἀ^νὰ^πτολί^εθρονὑ^πέτρεσα^νὄβριμουἄνδρα^
# Gold:     ὥσοἱἀ^νὰ^πτολί^εθρονὑ^πέτρεσα^νὄβρι^μουἄ^νδρα^
# Macronizer: ὥσοἱἀ^νὰ^πτολί^εθρονὑ^πέτρεσα^νὄβριμουἄνδρα^
# Gold:     μνησά^μενοιπροτέρωνὁπόσωνἀ^πὸθυ_μὸνἴ^απσεν
# Macronizer: μνησά^μενοιπροτέρωνὁπόσωνἀ^πὸθυ_μὸνἴ^α^πσεν
# Gold:     μνησά^μενοιπροτέρωνὁπόσωνἀ^πὸθυ_μὸνἴ^απσεν
# Macronizer: μνησά^μενοιπροτέρωνὁπόσωνἀ^πὸθυ_μὸνἴ^α^πσεν
# Gold:     μνησά^μενοιπροτέρωνὁπόσωνἀ^πὸθυ_μὸνἴ^απσεν
# Macronizer: μνησά^μενοιπροτέρωνὁπόσωνἀ^πὸθυ_μὸνἴ^α^πσεν
# Gold:     μνησά^μενοιπροτέρωνὁπόσωνἀ^πὸθυ_μὸνἴ^απσεν
# Macronizer: μνησά^μενοιπροτέρωνὁπόσωνἀ^πὸθυ_μὸνἴ^α^πσεν
# Gold:     θύ_ωνἰ_δαίοιοπερὶ^προχοῇσι^σκα^μάνδρου
# Macronizer: θύ_ωνἰ_δαίοιοπερὶ^προχοῇσι^σκα^μά^νδρου
# Gold:     θύ_ωνἰ_δαίοιοπερὶ^προχοῇσι^σκα^μάνδρου
# Macronizer: θύ_ωνἰ_δαίοιοπερὶ^προχοῇσι^σκα^μά^νδρου
# Gold:     θύ_ωνἰ_δαίοιοπερὶ^προχοῇσι^σκα^μάνδρου
# Macronizer: θύ_ωνἰ_δαίοιοπερὶ^προχοῇσι^σκα^μά^νδρου
# Gold:     θύ_ωνἰ_δαίοιοπερὶ^προχοῇσι^σκα^μάνδρου
# Macronizer: θύ_ωνἰ_δαίοιοπερὶ^προχοῇσι^σκα^μά^νδρου
# Gold:     θύ_ωνἰ_δαίοιοπερὶ^προχοῇσι^σκα^μάνδρου
# Macronizer: θύ_ωνἰ_δαίοιοπερὶ^προχοῇσι^σκα^μά^νδρου
# Gold:     ἄλλουσθὡσἐδά^ϊκσεδι^ἀ_κα^μά^τοιοθα^λάσσησ
# Macronizer: ἄλλουσθὡσἐδά^ϊκσεδι^ἀ^κα^μά^τοιοθα^λάσσησ
# Gold:     ἄλλουσθὡσἐδά^ϊκσεδι^ἀ_κα^μά^τοιοθα^λάσσησ
# Macronizer: ἄλλουσθὡσἐδά^ϊκσεδι^ἀ^κα^μά^τοιοθα^λάσσησ
# Gold:     ἄλλουσθὡσἐδά^ϊκσεδι^ἀ_κα^μά^τοιοθα^λάσσησ
# Macronizer: ἄλλουσθὡσἐδά^ϊκσεδι^ἀ^κα^μά^τοιοθα^λάσσησ
# Gold:     ἀμφὶ^δἄ^ρα^σφί^σι^πένθοσἀ^νι_ηρὸνπεπότητο
# Macronizer: ἀμφὶ^δἄ^ρα^σφί^σι^πένθοσἀ^νιηρὸνπεπότητο
# Gold:     ὡσἤδηστονόεντι^κα^ταιθομένησπυ^ρὶ^τροίησ
# Macronizer: ὡσἤδηστονόεντι^κα^ταιθομένησπυ_ρὶ^τροίησ
# Gold:     ὡσἤδηστονόεντι^κα^ταιθομένησπυ^ρὶ^τροίησ
# Macronizer: ὡσἤδηστονόεντι^κα^ταιθομένησπυ_ρὶ^τροίησ
# Gold:     ὡσἤδηστονόεντι^κα^ταιθομένησπυ^ρὶ^τροίησ
# Macronizer: ὡσἤδηστονόεντι^κα^ταιθομένησπυ_ρὶ^τροίησ
#
# === File: quintus.txt ===
# ^ success: 57/77 = 0.7403
# _ success: 1/7 = 0.1429
# Both success: 58/84 = 0.6905
# Line matches ignoring ^_: 20/20 = 1.0000
# Gold:     δωρί^δα^τὴνροδόπυ_γονὑ^πὲρλεχέωνδι^α^τείνα_σ
# Macronizer: δωρί^δα^τὴνροδόπυ_γονὑ^πὲρλεχέωνδια^τείνασ
# Gold:     δωρί^δα^τὴνροδόπυ_γονὑ^πὲρλεχέωνδι^α^τείνα_σ
# Macronizer: δωρί^δα^τὴνροδόπυ_γονὑ^πὲρλεχέωνδια^τείνασ
# Gold:     ἥγὰ^ρὑ^περφυ^έεσσιμέσονδι^α^βᾶσά^μεποσσὶ^ν
# Macronizer: ἥγὰ^ρὑ^περφυ^έεσσι^μέσονδι^α^βᾶσά^μεποσσὶ^ν
# Gold:     ἥγὰ^ρὑ^περφυ^έεσσιμέσονδι^α^βᾶσά^μεποσσὶ^ν
# Macronizer: ἥγὰ^ρὑ^περφυ^έεσσι^μέσονδι^α^βᾶσά^μεποσσὶ^ν
# Gold:     ἤνυ^σενἀκλι^νέωστὸνκύπρι^_δοσδόλι^χον
# Macronizer: ἤνυ^σενἀκλινέωστὸνκύπριδοσδόλιχον
# Gold:     ἤνυ^σενἀκλι^νέωστὸνκύπρι^_δοσδόλι^χον
# Macronizer: ἤνυ^σενἀκλινέωστὸνκύπριδοσδόλιχον
# Gold:     ἤνυ^σενἀκλι^νέωστὸνκύπρι^_δοσδόλι^χον
# Macronizer: ἤνυ^σενἀκλινέωστὸνκύπριδοσδόλιχον
# Gold:     ἤνυ^σενἀκλι^νέωστὸνκύπρι^_δοσδόλι^χον
# Macronizer: ἤνυ^σενἀκλινέωστὸνκύπριδοσδόλιχον
# Gold:     ὄμμα^σι^νωθρὰ^βλέπουσα^τὰ^δἠύτεπνεύμα^τι^φύλλα^
# Macronizer: ὄμμα^σι^νωθρὰ^βλέπουσα^τὰ^δἠύ^τεπνεύμα^τι^φύ^λλα^
# Gold:     ὄμμα^σι^νωθρὰ^βλέπουσα^τὰ^δἠύτεπνεύμα^τι^φύλλα^
# Macronizer: ὄμμα^σι^νωθρὰ^βλέπουσα^τὰ^δἠύ^τεπνεύμα^τι^φύ^λλα^
# Gold:     ὄμμα^σι^νωθρὰ^βλέπουσα^τὰ^δἠύτεπνεύμα^τι^φύλλα^
# Macronizer: ὄμμα^σι^νωθρὰ^βλέπουσα^τὰ^δἠύ^τεπνεύμα^τι^φύ^λλα^
# Gold:     ὄμμα^σι^νωθρὰ^βλέπουσα^τὰ^δἠύτεπνεύμα^τι^φύλλα^
# Macronizer: ὄμμα^σι^νωθρὰ^βλέπουσα^τὰ^δἠύ^τεπνεύμα^τι^φύ^λλα^
# Gold:     ὄμμα^σι^νωθρὰ^βλέπουσα^τὰ^δἠύτεπνεύμα^τι^φύλλα^
# Macronizer: ὄμμα^σι^νωθρὰ^βλέπουσα^τὰ^δἠύ^τεπνεύμα^τι^φύ^λλα^
# Gold:     ἀμφι^σα^λευομένησἔτρεμεπορφύ^ρεα^
# Macronizer: ἀμφισα^λευομένησἔτρεμεπορφύ^ρεα^
# Gold:     μέχρι^σἀ^πεσπείσθηλευκὸνμένοσἀμφοτέροισι^ν
# Macronizer: μέχρι^σἀ^πεσπείσθηλευκὸνμένοσἀ^μφοτέροισι^ν
# Gold:     μέχρι^σἀ^πεσπείσθηλευκὸνμένοσἀμφοτέροισι^ν
# Macronizer: μέχρι^σἀ^πεσπείσθηλευκὸνμένοσἀ^μφοτέροισι^ν
#
# === File: dioscorides.txt ===
# ^ success: 24/38 = 0.6316
# _ success: 2/4 = 0.5000
# Both success: 26/42 = 0.6190
# Line matches ignoring ^_: 8/8 = 1.0000
# Gold:     λόγῳὅσα^ἡμέτερα^ἔργα^οὐκἐφἡμῖνδὲτὸσῶμα^ἡκτῆσι^σ
# Macronizer: λόγῳὅσα^ἡμέτερα^ἔργα^οὐκἐφἡμῖνδὲτὸσῶ^μα^ἡκτῆσισ^
# Gold:     λόγῳὅσα^ἡμέτερα^ἔργα^οὐκἐφἡμῖνδὲτὸσῶμα^ἡκτῆσι^σ
# Macronizer: λόγῳὅσα^ἡμέτερα^ἔργα^οὐκἐφἡμῖνδὲτὸσῶ^μα^ἡκτῆσισ^
# Gold:     λόγῳὅσα^ἡμέτερα^ἔργα^οὐκἐφἡμῖνδὲτὸσῶμα^ἡκτῆσι^σ
# Macronizer: λόγῳὅσα^ἡμέτερα^ἔργα^οὐκἐφἡμῖνδὲτὸσῶ^μα^ἡκτῆσισ^
# Gold:     λόγῳὅσα^ἡμέτερα^ἔργα^οὐκἐφἡμῖνδὲτὸσῶμα^ἡκτῆσι^σ
# Macronizer: λόγῳὅσα^ἡμέτερα^ἔργα^οὐκἐφἡμῖνδὲτὸσῶ^μα^ἡκτῆσισ^
# Gold:     λόγῳὅσα^ἡμέτερα^ἔργα^οὐκἐφἡμῖνδὲτὸσῶμα^ἡκτῆσι^σ
# Macronizer: λόγῳὅσα^ἡμέτερα^ἔργα^οὐκἐφἡμῖνδὲτὸσῶ^μα^ἡκτῆσισ^
# Gold:     τὰ^μὲνἐφἡμῖνἐστι^φύ_σειἐλεύθερα^ἀ^κώλυ_τα^ἀ^πα^ρα^πόδιστα^
# Macronizer: τὰ^μὲνἐφἡμῖνἐστι^φύ^σειἐλεύθερα^ἀ^κώλυ_τα^ἀ^πα^ρα^πόδιστα^
# Gold:     τὰ^μὲνἐφἡμῖνἐστι^φύ_σειἐλεύθερα^ἀ^κώλυ_τα^ἀ^πα^ρα^πόδιστα^
# Macronizer: τὰ^μὲνἐφἡμῖνἐστι^φύ^σειἐλεύθερα^ἀ^κώλυ_τα^ἀ^πα^ρα^πόδιστα^
# Gold:     τὰ^μὲνἐφἡμῖνἐστι^φύ_σειἐλεύθερα^ἀ^κώλυ_τα^ἀ^πα^ρα^πόδιστα^
# Macronizer: τὰ^μὲνἐφἡμῖνἐστι^φύ^σειἐλεύθερα^ἀ^κώλυ_τα^ἀ^πα^ρα^πόδιστα^
# Gold:     μέμνησοοὖνὅτι^ἐὰ^ντὰ^φύ_σειδοῦλα^ἐλεύθερα^οἰηθῇσκαὶ
# Macronizer: μέμνησοοὖνὅτι^ἐὰ^ντὰ^φύ^σειδοῦλα^ἐλεύθερα^οἰηθῇσκαὶ
# Gold:     μέμνησοοὖνὅτι^ἐὰ^ντὰ^φύ_σειδοῦλα^ἐλεύθερα^οἰηθῇσκαὶ
# Macronizer: μέμνησοοὖνὅτι^ἐὰ^ντὰ^φύ^σειδοῦλα^ἐλεύθερα^οἰηθῇσκαὶ
# Gold:     μέμνησοοὖνὅτι^ἐὰ^ντὰ^φύ_σειδοῦλα^ἐλεύθερα^οἰηθῇσκαὶ
# Macronizer: μέμνησοοὖνὅτι^ἐὰ^ντὰ^φύ^σειδοῦλα^ἐλεύθερα^οἰηθῇσκαὶ
# Gold:     κεκι_νημένονἅπτεσθαιαὐτῶνἀλλὰ^τὰ^μὲνἀ^φι_έναι
# Macronizer: κεκινημένονἅπτεσθαιαὐτῶνἀλλὰ^τὰ^μὲνἀ^φι_έναι
#
# === File: enchiridion.txt ===
# ^ success: 72/81 = 0.8889
# _ success: 10/13 = 0.7692
# Both success: 82/94 = 0.8723
# Line matches ignoring ^_: 20/20 = 1.0000
# Gold:     ὅσα^δὴδέδηγμαιτὴνἐμαυτοῦκα^ρδία_ν
# Macronizer: ὅσα^δὴδέδηγμαιτὴνἐμαυτοῦκαρδί^α_ν
# Gold:     ὅσα^δὴδέδηγμαιτὴνἐμαυτοῦκα^ρδία_ν
# Macronizer: ὅσα^δὴδέδηγμαιτὴνἐμαυτοῦκαρδί^α_ν
# Gold:     ἥσθηνδὲβαιά^πά^νυδὲβαιά^τέττα^ρα^
# Macronizer: ἥσθηνδὲβαιά^πά^νυ^δὲβαιά^τέττα^ρα^
# Gold:     ἥσθηνδὲβαιά^πά^νυδὲβαιά^τέττα^ρα^
# Macronizer: ἥσθηνδὲβαιά^πά^νυ^δὲβαιά^τέττα^ρα^
# Gold:     ἃ^δὠδυ^νήθηνπσαμμα^κοσι^ογάργα^ρα^
# Macronizer: ἃ^δὠδυ^νήθηνπσαμμα^κοσιογάργα^ρα^
# Gold:     φέρἴ^δωτί^δἥσθηνἄκσι^ονχαιρηδόνοσ
# Macronizer: φέρἴ^δωτί^δἥσθηνἄ^κσι^ονχαιρηδόνοσ
# Gold:     φέρἴ^δωτί^δἥσθηνἄκσι^ονχαιρηδόνοσ
# Macronizer: φέρἴ^δωτί^δἥσθηνἄ^κσι^ονχαιρηδόνοσ
# Gold:     ἀλλαὐτὸσἔφερεπάντα^χὠπρί^ωνἀ^πῆν
# Macronizer: ἀλλαὐτὸσἔφερεπά^ντα^χὠπρί_ωνἀ^πῆν
# Gold:     ἀλλαὐτὸσἔφερεπάντα^χὠπρί^ωνἀ^πῆν
# Macronizer: ἀλλαὐτὸσἔφερεπά^ντα^χὠπρί_ωνἀ^πῆν
# Gold:     νῦνοὖνἀ^τεχνῶσἥκωπα^ρεσκευασμένοσ
# Macronizer: νῦνοὖνἀ^τεχνῶσἥκωπα^ρεσκευα^σμένοσ
# Gold:     νῦνοὖνἀ^τεχνῶσἥκωπα^ρεσκευασμένοσ
# Macronizer: νῦνοὖνἀ^τεχνῶσἥκωπα^ρεσκευα^σμένοσ
# Gold:     δι^ὰ^τοῦτοτοὔργονἄκσι^ονγὰ^ρἑλλά^δι^
# Macronizer: δι^ὰ^τοῦτοτοὔργονἄ^κσι^ονγὰ^ρἑλλά^δι^
# Gold:     ὁδἀ^νεῖπενεἴσα^γὦθέογνι^τὸνχορόν
# Macronizer: ὁδἀ^νεῖπενεἴσα_γὦθέογνι^τὸνχορόν
# Gold:     ὁδἀ^νεῖπενεἴσα^γὦθέογνι^τὸνχορόν
# Macronizer: ὁδἀ^νεῖπενεἴσα_γὦθέογνι^τὸνχορόν
# Gold:     ἀλλἕτερονἥσθηνἡνί^κἐπὶμόσχῳποτὲ
# Macronizer: ἀλλἕτερονἥσθηνἡνί^κἐπὶ^μόσχῳποτὲ
# Gold:     τῆτεσδἀ^πέθα^νονκαὶδιεστράφηνἰ^δών
# Macronizer: τῆτεσδἀ^πέθα^νονκαὶδιεστρά^φηνἰ^δών
# Gold:     τῆτεσδἀ^πέθα^νονκαὶδιεστράφηνἰ^δών
# Macronizer: τῆτεσδἀ^πέθα^νονκαὶδιεστρά^φηνἰ^δών
#
# === File: acharnenses.txt ===
# ^ success: 27/44 = 0.6136
# _ success: 2/2 = 1.0000
# Both success: 29/46 = 0.6304
# Line matches ignoring ^_: 16/16 = 1.0000
# Gold:     ἦπόλλἄ^ελπτἔνεστι^νἐντῷμα^κρῷβί^ῳφεῦ
# Macronizer: ἦπόλλἄ^ελπτἔνεστι^νἐντῷμακρῷβί^ῳφεῦ
# Gold:     ἐπεὶτί^σἄνποτἤλπι^σὦστρυ_μόδωρἀ^κοῦσαι
# Macronizer: ἐπεὶτί^σἄ^νποτἤλπι_σὦστρυ_μόδωρἀ^κοῦσαι
# Gold:     ἐπεὶτί^σἄνποτἤλπι^σὦστρυ_μόδωρἀ^κοῦσαι
# Macronizer: ἐπεὶτί^σἄ^νποτἤλπι_σὦστρυ_μόδωρἀ^κοῦσαι
# Gold:     ὡσἐμοῦγετὼκσύ^λωτὸνὦμονἐκσι^πώκα^τον
# Macronizer: ὡσἐμοῦγετὼκσύ^λωτὸνὦμονἐκσιπώκα^τον
# Gold:     μήμἀ^ποσβεσθὲνλά^θῃπρὸστῇτελευτῇτῆσὁδοῦ
# Macronizer: μήμἀ^ποσβεσθὲνλά_θῃπρὸστῇτελευτῇτῆσὁδοῦ
# Gold:     μήμἀ^ποσβεσθὲνλά^θῃπρὸστῇτελευτῇτῆσὁδοῦ
# Macronizer: μήμἀ^ποσβεσθὲνλά_θῃπρὸστῇτελευτῇτῆσὁδοῦ
# Gold:     ὡσδεινόνὦνακσἡρά^κλεισπροσπεσόνμἐκτῆσχύ^τρασ
# Macronizer: ὡσδεινόνὦνακσἡράκλεισπροσπεσόνμἐκτῆσχύ^τρα_σ
# Gold:     ὡσδεινόνὦνακσἡρά^κλεισπροσπεσόνμἐκτῆσχύ^τρασ
# Macronizer: ὡσδεινόνὦνακσἡράκλεισπροσπεσόνμἐκτῆσχύ^τρα_σ
# Gold:     ὥσπερκύ^ωνλυττῶσα^τὠφθαλμὼδά^κνει
# Macronizer: ὥσπερκύ^ωνλυττῶσα^τὠφθαλμὼδάκνει
# Gold:     οὐγὰ^ρἄνποθὧδὀδὰκσἔβρυ_κετὰσλήμα_σἐμοῦ
# Macronizer: οὐγὰ^ρἄ^νποθὧδὀδὰκσἔβρυ_κετὰ_σλήμα_σἐμοῦ
# Gold:     ἢπόταὐτῇμᾶλλονἢνῦνὦλά^χησἀρήκσομεν
# Macronizer: ἢπόταὐτῇμᾶλλονἢνῦνὦλά^χησἀ^ρήκσομεν
# Gold:     πέτουπέτουνι_κοδί^κηπρὶ^νἐμπεπρῆσθαικα^λύ^κηντεκαὶκρί^τυλλανπερι^φυ_σήτω
# Macronizer: πέτουπέτουνικοδί^κηπρὶ^νἐμπεπρῆσθαικα^λύ^κηντεκαὶκρί_τυλλα^νπεριφυ_σήτω
# Gold:     πέτουπέτουνι_κοδί^κηπρὶ^νἐμπεπρῆσθαικα^λύ^κηντεκαὶκρί^τυλλανπερι^φυ_σήτω
# Macronizer: πέτουπέτουνικοδί^κηπρὶ^νἐμπεπρῆσθαικα^λύ^κηντεκαὶκρί_τυλλα^νπεριφυ_σήτω
# Gold:     πέτουπέτουνι_κοδί^κηπρὶ^νἐμπεπρῆσθαικα^λύ^κηντεκαὶκρί^τυλλανπερι^φυ_σήτω
# Macronizer: πέτουπέτουνικοδί^κηπρὶ^νἐμπεπρῆσθαικα^λύ^κηντεκαὶκρί_τυλλα^νπεριφυ_σήτω
# Gold:     πέτουπέτουνι_κοδί^κηπρὶ^νἐμπεπρῆσθαικα^λύ^κηντεκαὶκρί^τυλλανπερι^φυ_σήτω
# Macronizer: πέτουπέτουνικοδί^κηπρὶ^νἐμπεπρῆσθαικα^λύ^κηντεκαὶκρί_τυλλα^νπεριφυ_σήτω
# Gold:     πέτουπέτουνι_κοδί^κηπρὶ^νἐμπεπρῆσθαικα^λύ^κηντεκαὶκρί^τυλλανπερι^φυ_σήτω
# Macronizer: πέτουπέτουνικοδί^κηπρὶ^νἐμπεπρῆσθαικα^λύ^κηντεκαὶκρί_τυλλα^νπεριφυ_σήτω
# Gold:     πέτουπέτουνι_κοδί^κηπρὶ^νἐμπεπρῆσθαικα^λύ^κηντεκαὶκρί^τυλλανπερι^φυ_σήτω
# Macronizer: πέτουπέτουνικοδί^κηπρὶ^νἐμπεπρῆσθαικα^λύ^κηντεκαὶκρί_τυλλα^νπεριφυ_σήτω
# Gold:     νυνδὴγὰ^ρἐμπλησα^μένητὴνὑ^δρί^ανκνεφαία_
# Macronizer: νυνδὴγὰ^ρἐμπλησα^μένητὴνὑδρί^ανκνεφαία^
# Gold:     νυνδὴγὰ^ρἐμπλησα^μένητὴνὑ^δρί^ανκνεφαία_
# Macronizer: νυνδὴγὰ^ρἐμπλησα^μένητὴνὑδρί^ανκνεφαία^
# Gold:     νυνδὴγὰ^ρἐμπλησα^μένητὴνὑ^δρί^ανκνεφαία_
# Macronizer: νυνδὴγὰ^ρἐμπλησα^μένητὴνὑδρί^ανκνεφαία^
# Gold:     νυνδὴγὰ^ρἐμπλησα^μένητὴνὑ^δρί^ανκνεφαία_
# Macronizer: νυνδὴγὰ^ρἐμπλησα^μένητὴνὑδρί^ανκνεφαία^
# Gold:     νυνδὴγὰ^ρἐμπλησα^μένητὴνὑ^δρί^ανκνεφαία_
# Macronizer: νυνδὴγὰ^ρἐμπλησα^μένητὴνὑδρί^ανκνεφαία^
# Gold:     μόλι^σἀ^πὸκρήνησὑ^πὄχλουκαὶθορύ^βουκαὶπα^τά^γουχυ^τρείου
# Macronizer: μόλι^σἀ^πὸκρήνησὑ^πὄχλουκαὶθορύ^βουκαὶπα^τά^γουχυτρείου
# Gold:     ἀ_ρα^μένηταῖσι^νἐμαῖσδημότι^σινκα_ομέναισ
# Macronizer: ἀ^ρα^μένηταῖσι^νἐμαῖσδημότισι^νκα^ομέναισ
# Gold:     ἀ_ρα^μένηταῖσι^νἐμαῖσδημότι^σινκα_ομέναισ
# Macronizer: ἀ^ρα^μένηταῖσι^νἐμαῖσδημότισι^νκα^ομέναισ
# Gold:     ἀ_ρα^μένηταῖσι^νἐμαῖσδημότι^σινκα_ομέναισ
# Macronizer: ἀ^ρα^μένηταῖσι^νἐμαῖσδημότισι^νκα^ομέναισ
# Gold:     ἀ_ρα^μένηταῖσι^νἐμαῖσδημότι^σινκα_ομέναισ
# Macronizer: ἀ^ρα^μένηταῖσι^νἐμαῖσδημότισι^νκα^ομέναισ
# Gold:     ἀ_ρα^μένηταῖσι^νἐμαῖσδημότι^σινκα_ομέναισ
# Macronizer: ἀ^ρα^μένηταῖσι^νἐμαῖσδημότισι^νκα^ομέναισ
# Gold:     ἤκουσα^γὰρτυ_φογέροντα_σἄνδρα^σἔρρεινστελέχηφέροντα^σὥσπερβα^λα^νεύσοντασ
# Macronizer: ἤκουσα^γὰ^ρτυ_φογέροντα^σἄ^νδρα^σἔρρεινστελέχηφέροντα^σὥσπερβα^λα^νεύσοντα^σ
# Gold:     ἤκουσα^γὰρτυ_φογέροντα_σἄνδρα^σἔρρεινστελέχηφέροντα^σὥσπερβα^λα^νεύσοντασ
# Macronizer: ἤκουσα^γὰ^ρτυ_φογέροντα^σἄ^νδρα^σἔρρεινστελέχηφέροντα^σὥσπερβα^λα^νεύσοντα^σ
# Gold:     ἤκουσα^γὰρτυ_φογέροντα_σἄνδρα^σἔρρεινστελέχηφέροντα^σὥσπερβα^λα^νεύσοντασ
# Macronizer: ἤκουσα^γὰ^ρτυ_φογέροντα^σἄ^νδρα^σἔρρεινστελέχηφέροντα^σὥσπερβα^λα^νεύσοντα^σ
# Gold:     ἤκουσα^γὰρτυ_φογέροντα_σἄνδρα^σἔρρεινστελέχηφέροντα^σὥσπερβα^λα^νεύσοντασ
# Macronizer: ἤκουσα^γὰ^ρτυ_φογέροντα^σἄ^νδρα^σἔρρεινστελέχηφέροντα^σὥσπερβα^λα^νεύσοντα^σ
# Gold:     ἤκουσα^γὰρτυ_φογέροντα_σἄνδρα^σἔρρεινστελέχηφέροντα^σὥσπερβα^λα^νεύσοντασ
# Macronizer: ἤκουσα^γὰ^ρτυ_φογέροντα^σἄ^νδρα^σἔρρεινστελέχηφέροντα^σὥσπερβα^λα^νεύσοντα^σ
# Gold:     ἤκουσα^γὰρτυ_φογέροντα_σἄνδρα^σἔρρεινστελέχηφέροντα^σὥσπερβα^λα^νεύσοντασ
# Macronizer: ἤκουσα^γὰ^ρτυ_φογέροντα^σἄ^νδρα^σἔρρεινστελέχηφέροντα^σὥσπερβα^λα^νεύσοντα^σ
# Gold:     ἤκουσα^γὰρτυ_φογέροντα_σἄνδρα^σἔρρεινστελέχηφέροντα^σὥσπερβα^λα^νεύσοντασ
# Macronizer: ἤκουσα^γὰ^ρτυ_φογέροντα^σἄ^νδρα^σἔρρεινστελέχηφέροντα^σὥσπερβα^λα^νεύσοντα^σ
# Gold:     ὡσπυ^ρὶ^χρὴτὰσμυ^σα^ρὰσγυ^ναῖκα^σἀνθρα^κεύειν
# Macronizer: ὡσπυ_ρὶ^χρὴτὰ_σμυ^σα^ρὰ_σγυ^ναῖκα^σἀνθρα^κεύειν
# Gold:     ὡσπυ^ρὶ^χρὴτὰσμυ^σα^ρὰσγυ^ναῖκα^σἀνθρα^κεύειν
# Macronizer: ὡσπυ_ρὶ^χρὴτὰ_σμυ^σα^ρὰ_σγυ^ναῖκα^σἀνθρα^κεύειν
# Gold:     ὡσπυ^ρὶ^χρὴτὰσμυ^σα^ρὰσγυ^ναῖκα^σἀνθρα^κεύειν
# Macronizer: ὡσπυ_ρὶ^χρὴτὰ_σμυ^σα^ρὰ_σγυ^ναῖκα^σἀνθρα^κεύειν
# Gold:     ὡσπυ^ρὶ^χρὴτὰσμυ^σα^ρὰσγυ^ναῖκα^σἀνθρα^κεύειν
# Macronizer: ὡσπυ_ρὶ^χρὴτὰ_σμυ^σα^ρὰ_σγυ^ναῖκα^σἀνθρα^κεύειν
# Gold:     ἅ_σὦθεά_μήποτἐγὼπιμπρα^μένα_σἴ^δοιμι^
# Macronizer: ἅ_σὦθεά^μήποτἐγὼπιμπρα^μένα_σἴ^δοιμι^
# Gold:     ἅ_σὦθεά_μήποτἐγὼπιμπρα^μένα_σἴ^δοιμι^
# Macronizer: ἅ_σὦθεά^μήποτἐγὼπιμπρα^μένα_σἴ^δοιμι^
# Gold:     ἀλλὰ^πολέμουκαὶμα^νι^ῶνρυ_σα^μένα_σἑλλά^δα^καὶπολί_τασ
# Macronizer: ἀλλὰ^πολέμουκαὶμα^νιῶνρυ_σα^μένα_σἑλλά^δα^καὶπολί_τα_σ
# Gold:     ἀλλὰ^πολέμουκαὶμα^νι^ῶνρυ_σα^μένα_σἑλλά^δα^καὶπολί_τασ
# Macronizer: ἀλλὰ^πολέμουκαὶμα^νιῶνρυ_σα^μένα_σἑλλά^δα^καὶπολί_τα_σ
# Gold:     ἀλλὰ^πολέμουκαὶμα^νι^ῶνρυ_σα^μένα_σἑλλά^δα^καὶπολί_τασ
# Macronizer: ἀλλὰ^πολέμουκαὶμα^νιῶνρυ_σα^μένα_σἑλλά^δα^καὶπολί_τα_σ
# Gold:     ἀλλὰ^πολέμουκαὶμα^νι^ῶνρυ_σα^μένα_σἑλλά^δα^καὶπολί_τασ
# Macronizer: ἀλλὰ^πολέμουκαὶμα^νιῶνρυ_σα^μένα_σἑλλά^δα^καὶπολί_τα_σ
# Gold:     ἀλλὰ^πολέμουκαὶμα^νι^ῶνρυ_σα^μένα_σἑλλά^δα^καὶπολί_τασ
# Macronizer: ἀλλὰ^πολέμουκαὶμα^νιῶνρυ_σα^μένα_σἑλλά^δα^καὶπολί_τα_σ
# Gold:     ἀλλὰ^πολέμουκαὶμα^νι^ῶνρυ_σα^μένα_σἑλλά^δα^καὶπολί_τασ
# Macronizer: ἀλλὰ^πολέμουκαὶμα^νιῶνρυ_σα^μένα_σἑλλά^δα^καὶπολί_τα_σ
# Gold:     ἀλλὰ^πολέμουκαὶμα^νι^ῶνρυ_σα^μένα_σἑλλά^δα^καὶπολί_τασ
# Macronizer: ἀλλὰ^πολέμουκαὶμα^νιῶνρυ_σα^μένα_σἑλλά^δα^καὶπολί_τα_σ
# Gold:     ἀλλὰ^πολέμουκαὶμα^νι^ῶνρυ_σα^μένα_σἑλλά^δα^καὶπολί_τασ
# Macronizer: ἀλλὰ^πολέμουκαὶμα^νιῶνρυ_σα^μένα_σἑλλά^δα^καὶπολί_τα_σ
# Gold:     ἐφοἷσπερὦχρυ_σολόφα_
# Macronizer: ἐφοἷσπερὦχρυ_σολόφα^
# Gold:     ἐφοἷσπερὦχρυ_σολόφα_
# Macronizer: ἐφοἷσπερὦχρυ_σολόφα^
# Gold:     πολι^οῦχεσὰ_σἔσχονἕδρασ
# Macronizer: πολιοῦχεσὰ_σἔσχονἕδρα_σ
# Gold:     πολι^οῦχεσὰ_σἔσχονἕδρασ
# Macronizer: πολιοῦχεσὰ_σἔσχονἕδρα_σ
# Gold:     τρι_τογένειἤντι^σἐκείνα_σὑ^ποπιμπρῇσι^νἀ^νήρ
# Macronizer: τριτογένειἤντι^σἐκείνα_σὑ^ποπιμπρῇσι^νἀ^νήρ
# Gold:     ἀ^κρόπολι^νἱ^ερὸντέμενοσ
# Macronizer: ἀκρόπολι^νἱ^ερὸντέμενοσ
# Gold:     οὐδὲγόνα^τἂνκόποσἕλοιμεκα^μα^τήρι^οσ
# Macronizer: οὐδὲγόνα^τἂ^νκόποσἕλοιμεκα^μα^τήριοσ
# Gold:     οὐδὲγόνα^τἂνκόποσἕλοιμεκα^μα^τήρι^οσ
# Macronizer: οὐδὲγόνα^τἂ^νκόποσἕλοιμεκα^μα^τήριοσ
# Gold:     μετὰ^τῶνδἀ^ρετῆσἕνεχαἷσἔνι^φύ^σισ
# Macronizer: μετὰ^τῶνδἀ^ρετῆσἕνεχαἷσἔνιφύ^σι^σ
# Gold:     μετὰ^τῶνδἀ^ρετῆσἕνεχαἷσἔνι^φύ^σισ
# Macronizer: μετὰ^τῶνδἀ^ρετῆσἕνεχαἷσἔνιφύ^σι^σ
# Gold:     μετὰ^τῶνδἀ^ρετῆσἕνεχαἷσἔνι^φύ^σισ
# Macronizer: μετὰ^τῶνδἀ^ρετῆσἕνεχαἷσἔνιφύ^σι^σ
# Gold:     μετὰ^τῶνδἀ^ρετῆσἕνεχαἷσἔνι^φύ^σισ
# Macronizer: μετὰ^τῶνδἀ^ρετῆσἕνεχαἷσἔνιφύ^σι^σ
# Gold:     ἔνι^χά^ρι^σἔνι^θρά^σοσἔνι^δὲτὸσοφόνἔνι^
# Macronizer: ἔνιχά^ρι^σἔνιθρά^σοσἔνιδὲτὸσοφόνἔνι
# Gold:     ἔνι^χά^ρι^σἔνι^θρά^σοσἔνι^δὲτὸσοφόνἔνι^
# Macronizer: ἔνιχά^ρι^σἔνιθρά^σοσἔνιδὲτὸσοφόνἔνι
# Gold:     ἔνι^χά^ρι^σἔνι^θρά^σοσἔνι^δὲτὸσοφόνἔνι^
# Macronizer: ἔνιχά^ρι^σἔνιθρά^σοσἔνιδὲτὸσοφόνἔνι
# Gold:     ἔνι^χά^ρι^σἔνι^θρά^σοσἔνι^δὲτὸσοφόνἔνι^
# Macronizer: ἔνιχά^ρι^σἔνιθρά^σοσἔνιδὲτὸσοφόνἔνι
# Gold:     φι^λόπολι^σἀ^ρετὴφρόνι^μοσ
# Macronizer: φι^λόπολι^σἀ^ρετὴφρόνιμοσ
# Gold:     ἀλλἐπα^ποδυ^ώμεθὦνδρεστουτῳὶ_τῷπρά_γμα^τι^
# Macronizer: ἀλλἐπα^ποδυ^ώμεθὦνδρεστουτῳὶ^τῷπράγμα^τι^
# Gold:     ἀλλἐπα^ποδυ^ώμεθὦνδρεστουτῳὶ_τῷπρά_γμα^τι^
# Macronizer: ἀλλἐπα^ποδυ^ώμεθὦνδρεστουτῳὶ^τῷπράγμα^τι^
# Gold:     ἀλλἐπα^ποδυ^ώμεθὦνδρεστουτῳὶ_τῷπρά_γμα^τι^
# Macronizer: ἀλλἐπα^ποδυ^ώμεθὦνδρεστουτῳὶ^τῷπράγμα^τι^
# Gold:     ἀλλἐπα^ποδυ^ώμεθὦνδρεστουτῳὶ_τῷπρά_γμα^τι^
# Macronizer: ἀλλἐπα^ποδυ^ώμεθὦνδρεστουτῳὶ^τῷπράγμα^τι^
# Gold:     ἤδηγὰ^ρὄδσειτα^δὶ_πλειόνων
# Macronizer: ἤδηγὰ^ρὄδσειτα^δὶπλειόνων
# Gold:     τὰσθεοῖσἐχθρὰσγυ^ναῖκα^σἐκσεπά_ρωσινδόλῳ
# Macronizer: τὰ_σθεοῖσἐχθρὰ_σγυ^ναῖκα^σἐκσεπά^ρωσι^νδόλῳ
# Gold:     τὰσθεοῖσἐχθρὰσγυ^ναῖκα^σἐκσεπά_ρωσινδόλῳ
# Macronizer: τὰ_σθεοῖσἐχθρὰ_σγυ^ναῖκα^σἐκσεπά^ρωσι^νδόλῳ
# Gold:     τὰσθεοῖσἐχθρὰσγυ^ναῖκα^σἐκσεπά_ρωσινδόλῳ
# Macronizer: τὰ_σθεοῖσἐχθρὰ_σγυ^ναῖκα^σἐκσεπά^ρωσι^νδόλῳ
# Gold:     κα^τα^λα^βεῖντὰ^χρήμα^θἡμῶντόντεμισθόνἔνθενἔδσωνἐγώ
# Macronizer: κα^τα^λα^βεῖντὰ^χρήμα_θἡμῶντόντεμισθόνἔνθενἔδσωνἐγώ
# Gold:     κα^τα^λα^βεῖντὰ^χρήμα^θἡμῶντόντεμισθόνἔνθενἔδσωνἐγώ
# Macronizer: κα^τα^λα^βεῖντὰ^χρήμα_θἡμῶντόντεμισθόνἔνθενἔδσωνἐγώ
# Gold:     κα^τα^λα^βεῖντὰ^χρήμα^θἡμῶντόντεμισθόνἔνθενἔδσωνἐγώ
# Macronizer: κα^τα^λα^βεῖντὰ^χρήμα_θἡμῶντόντεμισθόνἔνθενἔδσωνἐγώ
# Gold:     οὐκἄ^ρεἰσι^όντα^σοἴκα^δἡτεκοῦσα^γνώσεται
# Macronizer: οὐκἄ^ρεἰσιόντα^σοἴκα^δἡτεκοῦσα^γνώσεται
# Gold:     ἀλλὰ^θώμεσθὦφί^λαιγρᾶεστα^δὶ_πρῶτονχα^μαί
# Macronizer: ἀλλὰ^θώμεσθὦφί^λαιγρᾶεστα^δὶπρῶτονχα^μαί
# Gold:     εἰκότωσἐπεὶχλι^δῶσα^νἀ_γλα^ῶσἔθρεπσέμε
# Macronizer: εἰκότωσἐπεὶχλιδῶσα^νἀ_γλα^ῶσἔθρεπσέμε
# Gold:     εἶτἀ^λετρὶ^σἦδεκέτι^σοὖσα^τἀρχηγέτι^
# Macronizer: εἶτἀ^λετρὶ^σἦδεκέτισοὖσα^τἀρχηγέτι^
# Gold:     κἀ_κα^νηφόρουνποτοὖσα^παῖσκα^λὴχουσἰσχά^δωνὁρμα^θόν
# Macronizer: κἀ^κα^νηφόρουνποτοὖσα^παῖσκα^λὴχουσἰσχά^δωνὁρμα^θόν
# Gold:     ταῦτοὖνοὐχὕ^βριστὰ^πρά_γμα^τἐστὶ^πολλή
# Macronizer: ταῦτοὖνοὐχὕ^βριστὰ^πράγμα^τἐστὶ^πολλή
# Gold:     κἀ_πι^δώσεινμοιδοκεῖτὸχρῆμα^μᾶλλον
# Macronizer: κἀ^πιδώσεινμοιδοκεῖτὸχρῆμα^μᾶλλον
# Gold:     κἀ_πι^δώσεινμοιδοκεῖτὸχρῆμα^μᾶλλον
# Macronizer: κἀ^πιδώσεινμοιδοκεῖτὸχρῆμα^μᾶλλον
# Gold:     ἀλλἀ^μυντέοντὸπρᾶγμὅστισγἐνόρχησἔστἀ^νήρ
# Macronizer: ἀλλἀ^μυντέοντὸπρᾶγμὅστι^σγἐνόρχησἔστἀ^νήρ
# Gold:     ἀνδρὸσὄδσεινεὐθύ^σἀλλοὐκἐντεθρι_ῶσθαιπρέπει
# Macronizer: ἀνδρὸσὄδσεινεὐθύ^σἀλλοὐκἐντεθριῶσθαιπρέπει
# Gold:     ἀλλἄ^γετελευκόποδεσοἵπερἐπὶ^λειπσύ^δρι^ον
# Macronizer: ἀλλἄ^γετελευκόποδεσοἵπερἐπὶ^λειπσύδριον
# Gold:     ἀλλἄ^γετελευκόποδεσοἵπερἐπὶ^λειπσύ^δρι^ον
# Macronizer: ἀλλἄ^γετελευκόποδεσοἵπερἐπὶ^λειπσύδριον
# Gold:     νῦνδεῖνῦνἀ^νηβῆσαιπά^λινκἀ_ναπτερῶσαι
# Macronizer: νῦνδεῖνῦνἀ^νηβῆσαιπά^λι^νκἀ^ναπτερῶσαι
# Gold:     νῦνδεῖνῦνἀ^νηβῆσαιπά^λινκἀ_ναπτερῶσαι
# Macronizer: νῦνδεῖνῦνἀ^νηβῆσαιπά^λι^νκἀ^ναπτερῶσαι
# Gold:     νῦνδεῖνῦνἀ^νηβῆσαιπά^λινκἀ_ναπτερῶσαι
# Macronizer: νῦνδεῖνῦνἀ^νηβῆσαιπά^λι^νκἀ^ναπτερῶσαι
# Gold:     πᾶντὸσῶμα^κἀ_ποσείσασθαιτὸγῆραστόδε
# Macronizer: πᾶντὸσῶ^μα^κἀ^ποσείσασθαιτὸγῆρασ^τόδε
# Gold:     πᾶντὸσῶμα^κἀ_ποσείσασθαιτὸγῆραστόδε
# Macronizer: πᾶντὸσῶ^μα^κἀ^ποσείσασθαιτὸγῆρασ^τόδε
# Gold:     ὡσἂ^νὄδσωμενγυ^ναικῶναὐτοδὰκσὠργισμένων
# Macronizer: ὡσἂ_νὄδσωμενγυ^ναικῶναὐτοδὰκσὠργισμένων
# Gold:     νῦνπρὸσἔμἴ^τωτι^σἵ^να^μήποτεφά^γῃσκόροδα^
# Macronizer: νῦνπρὸσἔμἴ^τωτι^σἵ^να_μήποτεφά^γῃσκόροδα^
# Gold:     νῦνπρὸσἔμἴ^τωτι^σἵ^να^μήποτεφά^γῃσκόροδα^
# Macronizer: νῦνπρὸσἔμἴ^τωτι^σἵ^να_μήποτεφά^γῃσκόροδα^
# Gold:     νῦνπρὸσἔμἴ^τωτι^σἵ^να^μήποτεφά^γῃσκόροδα^
# Macronizer: νῦνπρὸσἔμἴ^τωτι^σἵ^να_μήποτεφά^γῃσκόροδα^
# Gold:     νῦνπρὸσἔμἴ^τωτι^σἵ^να^μήποτεφά^γῃσκόροδα^
# Macronizer: νῦνπρὸσἔμἴ^τωτι^σἵ^να_μήποτεφά^γῃσκόροδα^
# Gold:     μηδὲκυ^ά^μουσμέλα^νασ
# Macronizer: μηδὲκυ^ά^μουσμέλα^να^σ
# Gold:     μηδὲκυ^ά^μουσμέλα^νασ
# Macronizer: μηδὲκυ^ά^μουσμέλα^να^σ
# Gold:     μηδὲκυ^ά^μουσμέλα^νασ
# Macronizer: μηδὲκυ^ά^μουσμέλα^να^σ
# Gold:     ὡσεἰκαὶμόνονκα^κῶσἐρεῖσὑ^περχολῶγάρ
# Macronizer: ὡσεἰκαὶμόνονκα^κῶσἐρεῖσὑ^περχολῶγά^ρ
# Gold:     ὡσεἰκαὶμόνονκα^κῶσἐρεῖσὑ^περχολῶγάρ
# Macronizer: ὡσεἰκαὶμόνονκα^κῶσἐρεῖσὑ^περχολῶγά^ρ
# Gold:     μῦθονβούλομαιλέκσαιτι^νὑ_μῖνὅνποτἤκουσαὐτὸσἔτι^παῖσὤν
# Macronizer: μῦθονβούλομαιλέκσαιτινὑ_μῖνὅνποτἤκουσαὐτὸσἔτι^παῖσὤν
# Gold:     πλεκσά^μενοσἄρκυσ
# Macronizer: πλεκσά^μενοσἄ^ρκυ_σ
# Gold:     κοὐκέτι^κα^τῆλθεπά^λι^νοἴκα^δὑ^πὸμί_σουσ
# Macronizer: κοὐκέτι^κα^τῆλθεπά^λι^νοἴκα^δὑ^πὸμί^σουσ
# Gold:     κοὐκέτι^κα^τῆλθεπά^λι^νοἴκα^δὑ^πὸμί_σουσ
# Macronizer: κοὐκέτι^κα^τῆλθεπά^λι^νοἴκα^δὑ^πὸμί^σουσ
# Gold:     κοὐκέτι^κα^τῆλθεπά^λι^νοἴκα^δὑ^πὸμί_σουσ
# Macronizer: κοὐκέτι^κα^τῆλθεπά^λι^νοἴκα^δὑ^πὸμί^σουσ
# Gold:     κοὐκέτι^κα^τῆλθεπά^λι^νοἴκα^δὑ^πὸμί_σουσ
# Macronizer: κοὐκέτι^κα^τῆλθεπά^λι^νοἴκα^δὑ^πὸμί^σουσ
# Gold:     κοὐκέτι^κα^τῆλθεπά^λι^νοἴκα^δὑ^πὸμί_σουσ
# Macronizer: κοὐκέτι^κα^τῆλθεπά^λι^νοἴκα^δὑ^πὸμί^σουσ
# Gold:     κοὐκέτι^κα^τῆλθεπά^λι^νοἴκα^δὑ^πὸμί_σουσ
# Macronizer: κοὐκέτι^κα^τῆλθεπά^λι^νοἴκα^δὑ^πὸμί^σουσ
# Gold:     κοὐκέτι^κα^τῆλθεπά^λι^νοἴκα^δὑ^πὸμί_σουσ
# Macronizer: κοὐκέτι^κα^τῆλθεπά^λι^νοἴκα^δὑ^πὸμί^σουσ
# Gold:     κἀ_γὼβούλομαιμῦθόντι^νὑ_μῖνἀντι^λέκσαιτῷμελα^νί^ωνι^
# Macronizer: κἀ^γὼβούλομαιμῦθόντινὑ_μῖνἀντιλέκσαιτῷμελα^νί^ωνι^
# Gold:     κἀ_γὼβούλομαιμῦθόντι^νὑ_μῖνἀντι^λέκσαιτῷμελα^νί^ωνι^
# Macronizer: κἀ^γὼβούλομαιμῦθόντινὑ_μῖνἀντιλέκσαιτῷμελα^νί^ωνι^
# Gold:     κἀ_γὼβούλομαιμῦθόντι^νὑ_μῖνἀντι^λέκσαιτῷμελα^νί^ωνι^
# Macronizer: κἀ^γὼβούλομαιμῦθόντινὑ_μῖνἀντιλέκσαιτῷμελα^νί^ωνι^
# Gold:     ᾤχεθὑ^πὸμί_σουσ
# Macronizer: ᾤχεθὑ^πὸμί^σουσ
# Gold:     ᾤχεθὑ^πὸμί_σουσ
# Macronizer: ᾤχεθὑ^πὸμί^σουσ
# Gold:     πολλὰ^κα^τα^ρα_σά^μενοσἀνδρά^σι^πονηροῖσ
# Macronizer: πολλὰ^κα^τα^ρα_σά^μενοσἀ^νδρά^σι^πονηροῖσ
# Gold:     πολλὰ^κα^τα^ρα_σά^μενοσἀνδρά^σι^πονηροῖσ
# Macronizer: πολλὰ^κα^τα^ρα_σά^μενοσἀ^νδρά^σι^πονηροῖσ
# Gold:     πολλὰ^κα^τα^ρα_σά^μενοσἀνδρά^σι^πονηροῖσ
# Macronizer: πολλὰ^κα^τα^ρα_σά^μενοσἀ^νδρά^σι^πονηροῖσ
# Gold:     πολλὰ^κα^τα^ρα_σά^μενοσἀνδρά^σι^πονηροῖσ
# Macronizer: πολλὰ^κα^τα^ρα_σά^μενοσἀ^νδρά^σι^πονηροῖσ
# Gold:     πολλὰ^κα^τα^ρα_σά^μενοσἀνδρά^σι^πονηροῖσ
# Macronizer: πολλὰ^κα^τα^ρα_σά^μενοσἀ^νδρά^σι^πονηροῖσ
# Gold:     οὐπα^ρασκευαδσόμεσθα^τῶνπολι_τῶνοὐδένὦνδρεσφλαῦρονεἰπεῖνοὐδὲἕν
# Macronizer: οὐπα^ρα^σκευα^δσόμεσθα^τῶνπολι_τῶνοὐδένὦνδρεσφλαῦρονεἰπεῖνοὐδὲἕν
# Gold:     ἀλλὰ^πολὺ^τοὔμπα^λινπάντἀ^γα^θὰ^καὶλέγειν
# Macronizer: ἀλλὰ^πολὺ^τοὔμπα^λι^νπάντἀ^γα^θὰ^καὶλέγειν
# Gold:     ἀλλὰ^πολὺ^τοὔμπα^λινπάντἀ^γα^θὰ^καὶλέγειν
# Macronizer: ἀλλὰ^πολὺ^τοὔμπα^λι^νπάντἀ^γα^θὰ^καὶλέγειν
# Gold:     ἀλλὰ^πολὺ^τοὔμπα^λινπάντἀ^γα^θὰ^καὶλέγειν
# Macronizer: ἀλλὰ^πολὺ^τοὔμπα^λι^νπάντἀ^γα^θὰ^καὶλέγειν
# Gold:     καὶδρᾶνἱ^κα^νὰ^γὰρτὰ^κα^κὰ^καὶτὰ^πα^ρα^κείμενα^
# Macronizer: καὶδρᾶνἱ^κα^νὰ^γὰ^ρτὰ^κα^κὰ^καὶτὰ^πα^ρα^κείμενα^
# Gold:     καὶδρᾶνἱ^κα^νὰ^γὰρτὰ^κα^κὰ^καὶτὰ^πα^ρα^κείμενα^
# Macronizer: καὶδρᾶνἱ^κα^νὰ^γὰ^ρτὰ^κα^κὰ^καὶτὰ^πα^ρα^κείμενα^
# Gold:     εἴτι^σἀργυ^ρί_δι^ον
# Macronizer: εἴτι^σἀργυ^ρί_διον
# Gold:     δεῖταιλα^βεῖνμνᾶσἢδύ^ἢτρεῖσὡσἔσωστὶνκἄ_χομενβαλλάντι^α^
# Macronizer: δεῖταιλα^βεῖνμνᾶσἢδύ_ἢτρεῖσὡσἔσωστὶνκἄ^χομενβα^λλά^ντι^α^
# Gold:     δεῖταιλα^βεῖνμνᾶσἢδύ^ἢτρεῖσὡσἔσωστὶνκἄ_χομενβαλλάντι^α^
# Macronizer: δεῖταιλα^βεῖνμνᾶσἢδύ_ἢτρεῖσὡσἔσωστὶνκἄ^χομενβα^λλά^ντι^α^
# Gold:     δεῖταιλα^βεῖνμνᾶσἢδύ^ἢτρεῖσὡσἔσωστὶνκἄ_χομενβαλλάντι^α^
# Macronizer: δεῖταιλα^βεῖνμνᾶσἢδύ_ἢτρεῖσὡσἔσωστὶνκἄ^χομενβα^λλά^ντι^α^
# Gold:     ὅστι^σἂννυ_νὶ_δα^νείσηταιπα^ρἡμῶνἢνλά^βῃμηκέτἀ^ποδῷ
# Macronizer: ὅστι^σἂ_ννυ_νὶ_δα^νείσηταιπα^ρἡμῶνἢνλά^βῃμηκέτἀ^ποδῷ
# Gold:     ἑστι^ᾶνδὲμέλλομενκσένουστι^νὰσκα^ρυστί^ουσἄνδρασκα^λούστεκἀ_γα^θούσ
# Macronizer: ἑστιᾶνδὲμέλλομενκσένουστι^νὰ^σκα^ρυστί^ουσἄ^νδρα^σκα^λούστεκἀ^γα^θούσ
# Gold:     ἑστι^ᾶνδὲμέλλομενκσένουστι^νὰσκα^ρυστί^ουσἄνδρασκα^λούστεκἀ_γα^θούσ
# Macronizer: ἑστιᾶνδὲμέλλομενκσένουστι^νὰ^σκα^ρυστί^ουσἄ^νδρα^σκα^λούστεκἀ^γα^θούσ
# Gold:     ἑστι^ᾶνδὲμέλλομενκσένουστι^νὰσκα^ρυστί^ουσἄνδρασκα^λούστεκἀ_γα^θούσ
# Macronizer: ἑστιᾶνδὲμέλλομενκσένουστι^νὰ^σκα^ρυστί^ουσἄ^νδρα^σκα^λούστεκἀ^γα^θούσ
# Gold:     ἑστι^ᾶνδὲμέλλομενκσένουστι^νὰσκα^ρυστί^ουσἄνδρασκα^λούστεκἀ_γα^θούσ
# Macronizer: ἑστιᾶνδὲμέλλομενκσένουστι^νὰ^σκα^ρυστί^ουσἄ^νδρα^σκα^λούστεκἀ^γα^θούσ
# Gold:     ἑστι^ᾶνδὲμέλλομενκσένουστι^νὰσκα^ρυστί^ουσἄνδρασκα^λούστεκἀ_γα^θούσ
# Macronizer: ἑστιᾶνδὲμέλλομενκσένουστι^νὰ^σκα^ρυστί^ουσἄ^νδρα^σκα^λούστεκἀ^γα^θούσ
# Gold:     κἄστι^νἔτνοστι^καὶδελφά^κι^ονἦντί^μοι
# Macronizer: κἄστινἔτνοστι^καὶδελφά^κιονἦντί^μοι
# Gold:     κἄστι^νἔτνοστι^καὶδελφά^κι^ονἦντί^μοι
# Macronizer: κἄστινἔτνοστι^καὶδελφά^κιονἦντί^μοι
# Gold:     αὐτούστεκαὶτὰ^παιδί^εἶτεἴσωβα^δίδσεινμηδἐρέσθαιμηδένα^
# Macronizer: αὐτούστεκαὶτὰ^παιδί^εἶτεἴσωβα^δί^δσεινμηδἐρέσθαιμηδένα^
# Gold:     αὐτούστεκαὶτὰ^παιδί^εἶτεἴσωβα^δίδσεινμηδἐρέσθαιμηδένα^
# Macronizer: αὐτούστεκαὶτὰ^παιδί^εἶτεἴσωβα^δί^δσεινμηδἐρέσθαιμηδένα^
# Gold:     αὐτούστεκαὶτὰ^παιδί^εἶτεἴσωβα^δίδσεινμηδἐρέσθαιμηδένα^
# Macronizer: αὐτούστεκαὶτὰ^παιδί^εἶτεἴσωβα^δί^δσεινμηδἐρέσθαιμηδένα^
# Gold:     ἀλλὰ^χωρεῖνἄντι^κρυσ
# Macronizer: ἀλλὰ^χωρεῖνἄντι^κρυ^σ
# Gold:     ἀλλὰ^χωρεῖνἄντι^κρυσ
# Macronizer: ἀλλὰ^χωρεῖνἄντι^κρυ^σ
# Gold:     ὥσπεροἴκα^δεἰσἑαυτῶνγεννι^κῶσὡσἡθύ^ρα_κεκλείσεται
# Macronizer: ὥσπεροἴκα^δεἰσἑαυτῶνγεννικῶσὡσἡθύ^ρα_κεκλείσεται
# Gold:     στρωμά^τωνδὲποικί^λωνκαὶχλα^νι^δί^ωνκαὶκσυστί^δωνκαὶχρυ_σί^ωνὅσἐστί^μοι
# Macronizer: στρωμά^τωνδὲποικί^λωνκαὶχλα^νιδί^ωνκαὶκσυστί^δωνκαὶχρυ_σί^ωνὅσἐστί^μοι
# Gold:     τοῖσπαισί^νὁπόταντεθυ^γά^τηρτι^νὶ^κα^νηφορῇ
# Macronizer: τοῖσπαισί^νὁπότα^ντεθυ^γά^τηρτι^νὶ^κα^νηφορῇ
# Gold:     πᾶσι^νὑ_μῖνλέγωλαμβά^νειντῶνἐμῶν
# Macronizer: πᾶσι^νὑ_μῖνλέγωλα^μβά^νειντῶνἐμῶν
# Gold:     πᾶσι^νὑ_μῖνλέγωλαμβά^νειντῶνἐμῶν
# Macronizer: πᾶσι^νὑ_μῖνλέγωλα^μβά^νειντῶνἐμῶν
# Gold:     χἄττἂ^νἔνδονᾖφορεῖν
# Macronizer: χἄττἂ_νἔνδονᾖφορεῖν
# Gold:     εἰδέτῳμὴσῖτοσὑ_μῶνἐστι^βόσκειδοἰκέτασκαὶσμι_κρὰ^πολλὰ^παιδί^α_
# Macronizer: εἰδέτῳμὴσῖτοσὑ_μῶνἐστι^βόσκειδοἰκέτα_σκαὶσμικρὰ^πολλὰ^παιδί^α^
# Gold:     εἰδέτῳμὴσῖτοσὑ_μῶνἐστι^βόσκειδοἰκέτασκαὶσμι_κρὰ^πολλὰ^παιδί^α_
# Macronizer: εἰδέτῳμὴσῖτοσὑ_μῶνἐστι^βόσκειδοἰκέτα_σκαὶσμικρὰ^πολλὰ^παιδί^α^
# Gold:     εἰδέτῳμὴσῖτοσὑ_μῶνἐστι^βόσκειδοἰκέτασκαὶσμι_κρὰ^πολλὰ^παιδί^α_
# Macronizer: εἰδέτῳμὴσῖτοσὑ_μῶνἐστι^βόσκειδοἰκέτα_σκαὶσμικρὰ^πολλὰ^παιδί^α^
# Gold:     εἰδέτῳμὴσῖτοσὑ_μῶνἐστι^βόσκειδοἰκέτασκαὶσμι_κρὰ^πολλὰ^παιδί^α_
# Macronizer: εἰδέτῳμὴσῖτοσὑ_μῶνἐστι^βόσκειδοἰκέτα_σκαὶσμικρὰ^πολλὰ^παιδί^α^
# Gold:     εἰδέτῳμὴσῖτοσὑ_μῶνἐστι^βόσκειδοἰκέτασκαὶσμι_κρὰ^πολλὰ^παιδί^α_
# Macronizer: εἰδέτῳμὴσῖτοσὑ_μῶνἐστι^βόσκειδοἰκέτα_σκαὶσμικρὰ^πολλὰ^παιδί^α^
# Gold:     εἰδέτῳμὴσῖτοσὑ_μῶνἐστι^βόσκειδοἰκέτασκαὶσμι_κρὰ^πολλὰ^παιδί^α_
# Macronizer: εἰδέτῳμὴσῖτοσὑ_μῶνἐστι^βόσκειδοἰκέτα_σκαὶσμικρὰ^πολλὰ^παιδί^α^
# Gold:     εἰδέτῳμὴσῖτοσὑ_μῶνἐστι^βόσκειδοἰκέτασκαὶσμι_κρὰ^πολλὰ^παιδί^α_
# Macronizer: εἰδέτῳμὴσῖτοσὑ_μῶνἐστι^βόσκειδοἰκέτα_σκαὶσμικρὰ^πολλὰ^παιδί^α^
# Gold:     ἔστι^πα^ρἐμοῦλα^βεῖνπυ_ρί^δι^α^λεπτὰ^μέν
# Macronizer: ἔστι^πα^ρἐμοῦλα^βεῖνπυ^ρί^δι^α^λεπτὰ^μέν
# Gold:     ἔστι^πα^ρἐμοῦλα^βεῖνπυ_ρί^δι^α^λεπτὰ^μέν
# Macronizer: ἔστι^πα^ρἐμοῦλα^βεῖνπυ^ρί^δι^α^λεπτὰ^μέν
# Gold:     ἔστι^πα^ρἐμοῦλα^βεῖνπυ_ρί^δι^α^λεπτὰ^μέν
# Macronizer: ἔστι^πα^ρἐμοῦλα^βεῖνπυ^ρί^δι^α^λεπτὰ^μέν
# Gold:     ὁδἄρτοσἀ^πὸχοίνι^κοσἰ^δεῖνμά^λα^νεα_νί^ασ
# Macronizer: ὁδἄρτοσἀ^πὸχοίνικοσἰ^δεῖνμά^λα_νεα_νί^α_σ
# Gold:     ὁδἄρτοσἀ^πὸχοίνι^κοσἰ^δεῖνμά^λα^νεα_νί^ασ
# Macronizer: ὁδἄρτοσἀ^πὸχοίνικοσἰ^δεῖνμά^λα_νεα_νί^α_σ
# Gold:     ὁδἄρτοσἀ^πὸχοίνι^κοσἰ^δεῖνμά^λα^νεα_νί^ασ
# Macronizer: ὁδἄρτοσἀ^πὸχοίνικοσἰ^δεῖνμά^λα_νεα_νί^α_σ
# Gold:     ὁδἄρτοσἀ^πὸχοίνι^κοσἰ^δεῖνμά^λα^νεα_νί^ασ
# Macronizer: ὁδἄρτοσἀ^πὸχοίνικοσἰ^δεῖνμά^λα_νεα_νί^α_σ
# Gold:     ὁδἄρτοσἀ^πὸχοίνι^κοσἰ^δεῖνμά^λα^νεα_νί^ασ
# Macronizer: ὁδἄρτοσἀ^πὸχοίνικοσἰ^δεῖνμά^λα_νεα_νί^α_σ
# Gold:     ὁδἄρτοσἀ^πὸχοίνι^κοσἰ^δεῖνμά^λα^νεα_νί^ασ
# Macronizer: ὁδἄρτοσἀ^πὸχοίνικοσἰ^δεῖνμά^λα_νεα_νί^α_σ
# Gold:     ὁδἄρτοσἀ^πὸχοίνι^κοσἰ^δεῖνμά^λα^νεα_νί^ασ
# Macronizer: ὁδἄρτοσἀ^πὸχοίνικοσἰ^δεῖνμά^λα_νεα_νί^α_σ
# Gold:     καὶκωρύ^κουσὡσλήπσεταιπυ_ρούσὁμα_νῆσδοὑμὸσαὐτοῖσἐμβα^λεῖ
# Macronizer: καὶκωρύ^κουσὡσλήπσεταιπυ_ρούσὁμα^νῆσδοὑμὸσαὐτοῖσἐμβα^λεῖ
# Gold:     καὶκωρύ^κουσὡσλήπσεταιπυ_ρούσὁμα_νῆσδοὑμὸσαὐτοῖσἐμβα^λεῖ
# Macronizer: καὶκωρύ^κουσὡσλήπσεταιπυ_ρούσὁμα^νῆσδοὑμὸσαὐτοῖσἐμβα^λεῖ
# Gold:     καὶκωρύ^κουσὡσλήπσεταιπυ_ρούσὁμα_νῆσδοὑμὸσαὐτοῖσἐμβα^λεῖ
# Macronizer: καὶκωρύ^κουσὡσλήπσεταιπυ_ρούσὁμα^νῆσδοὑμὸσαὐτοῖσἐμβα^λεῖ
# Gold:     προα^γορεύωμὴβα^δίδσειντὴνἐμήνἀλλεὐλα^βεῖσθαιτὴνκύ^να^
# Macronizer: προα^γορεύωμὴβα^δί^δσειντὴνἐμήνἀλλεὐλα^βεῖσθαιτὴνκύ^να^
# Gold:     προα^γορεύωμὴβα^δίδσειντὴνἐμήνἀλλεὐλα^βεῖσθαιτὴνκύ^να^
# Macronizer: προα^γορεύωμὴβα^δί^δσειντὴνἐμήνἀλλεὐλα^βεῖσθαιτὴνκύ^να^
# Gold:     χωρῶμενεἰσἐκκλησί^α_νὦνδρεσἠπείλησεγὰρ
# ...
# Gold:     μηδένὦτᾶνδέδι^θι^μηδένὡσἐγὼτοῦτόνγἐὰνγρύκσῃτι^ποιήσωδα^κεῖντὴνκαρδί^ανκαὶτὸνπερὶπσυ_χῆσδρόμονδρα^μεῖνἵ^νεἰδῇμὴπα^τεῖντὰ^ταῖνθεαῖνπσηφίσμα^τα^
# Macronizer: μηδένὦτᾶνδέδιθι^μηδένὡσἐγὼτοῦτόνγἐὰ^νγρύκσῃτι^ποιήσωδα^κεῖντὴνκαρδί^α_νκαὶτὸνπερὶ^πσυ_χῆσδρόμονδρα^μεῖνἵ^νεἰδῇμὴπα^τεῖντὰ^ταῖνθεαῖνπσηφί^σμα^τα^
# Gold:     μηδένὦτᾶνδέδι^θι^μηδένὡσἐγὼτοῦτόνγἐὰνγρύκσῃτι^ποιήσωδα^κεῖντὴνκαρδί^ανκαὶτὸνπερὶπσυ_χῆσδρόμονδρα^μεῖνἵ^νεἰδῇμὴπα^τεῖντὰ^ταῖνθεαῖνπσηφίσμα^τα^
# Macronizer: μηδένὦτᾶνδέδιθι^μηδένὡσἐγὼτοῦτόνγἐὰ^νγρύκσῃτι^ποιήσωδα^κεῖντὴνκαρδί^α_νκαὶτὸνπερὶ^πσυ_χῆσδρόμονδρα^μεῖνἵ^νεἰδῇμὴπα^τεῖντὰ^ταῖνθεαῖνπσηφί^σμα^τα^
# Gold:     μηδένὦτᾶνδέδι^θι^μηδένὡσἐγὼτοῦτόνγἐὰνγρύκσῃτι^ποιήσωδα^κεῖντὴνκαρδί^ανκαὶτὸνπερὶπσυ_χῆσδρόμονδρα^μεῖνἵ^νεἰδῇμὴπα^τεῖντὰ^ταῖνθεαῖνπσηφίσμα^τα^
# Macronizer: μηδένὦτᾶνδέδιθι^μηδένὡσἐγὼτοῦτόνγἐὰ^νγρύκσῃτι^ποιήσωδα^κεῖντὴνκαρδί^α_νκαὶτὸνπερὶ^πσυ_χῆσδρόμονδρα^μεῖνἵ^νεἰδῇμὴπα^τεῖντὰ^ταῖνθεαῖνπσηφί^σμα^τα^
# Gold:     μηδένὦτᾶνδέδι^θι^μηδένὡσἐγὼτοῦτόνγἐὰνγρύκσῃτι^ποιήσωδα^κεῖντὴνκαρδί^ανκαὶτὸνπερὶπσυ_χῆσδρόμονδρα^μεῖνἵ^νεἰδῇμὴπα^τεῖντὰ^ταῖνθεαῖνπσηφίσμα^τα^
# Macronizer: μηδένὦτᾶνδέδιθι^μηδένὡσἐγὼτοῦτόνγἐὰ^νγρύκσῃτι^ποιήσωδα^κεῖντὴνκαρδί^α_νκαὶτὸνπερὶ^πσυ_χῆσδρόμονδρα^μεῖνἵ^νεἰδῇμὴπα^τεῖντὰ^ταῖνθεαῖνπσηφί^σμα^τα^
# Gold:     μηδένὦτᾶνδέδι^θι^μηδένὡσἐγὼτοῦτόνγἐὰνγρύκσῃτι^ποιήσωδα^κεῖντὴνκαρδί^ανκαὶτὸνπερὶπσυ_χῆσδρόμονδρα^μεῖνἵ^νεἰδῇμὴπα^τεῖντὰ^ταῖνθεαῖνπσηφίσμα^τα^
# Macronizer: μηδένὦτᾶνδέδιθι^μηδένὡσἐγὼτοῦτόνγἐὰ^νγρύκσῃτι^ποιήσωδα^κεῖντὴνκαρδί^α_νκαὶτὸνπερὶ^πσυ_χῆσδρόμονδρα^μεῖνἵ^νεἰδῇμὴπα^τεῖντὰ^ταῖνθεαῖνπσηφί^σμα^τα^
# Gold:     ἐνεγκά^τωμοιδεῦροτὴνκίστηντι^σὡστά^χιστα^
# Macronizer: ἐνεγκά^τωμοιδεῦροτὴνκίστηντι^σὡστά^χι^στα^
# Gold:     ἐνεγκά^τωμοιδεῦροτὴνκίστηντι^σὡστά^χιστα^
# Macronizer: ἐνεγκά^τωμοιδεῦροτὴνκίστηντι^σὡστά^χι^στα^
# Gold:     ἐνεγκά^τωμοιδεῦροτὴνκίστηντι^σὡστά^χιστα^
# Macronizer: ἐνεγκά^τωμοιδεῦροτὴνκίστηντι^σὡστά^χι^στα^
# Gold:     ἀ^τὰρφα^νεῖποῖόστι^σὤνἢνταῦτα^πα^ρα^κελεύῃ
# Macronizer: ἀ^τὰ^ρφα^νεῖποῖόστι^σὤνἢνταῦτα^πα^ρα^κελεύῃ
# Gold:     τόνδελέγεινὁρᾷσγὰρὥσσοιμέγα^σἐστὶ^νἁ_γὼν
# Macronizer: τόνδελέγεινὁρᾷσγὰ^ρὥσσοιμέγα^σἐστὶ^νἁ^γὼν
# Gold:     τόνδελέγεινὁρᾷσγὰρὥσσοιμέγα^σἐστὶ^νἁ_γὼν
# Macronizer: τόνδελέγεινὁρᾷσγὰ^ρὥσσοιμέγα^σἐστὶ^νἁ^γὼν
# Gold:     τόνδελέγεινὁρᾷσγὰρὥσσοιμέγα^σἐστὶ^νἁ_γὼν
# Macronizer: τόνδελέγεινὁρᾷσγὰ^ρὥσσοιμέγα^σἐστὶ^νἁ^γὼν
# Gold:     καὶπερὶ^τῶνἁ^πάντων
# Macronizer: καὶπερὶ^τῶνἁ^πά^ντων
# Gold:     καὶπερὶ^τῶνἁ^πάντων
# Macronizer: καὶπερὶ^τῶνἁ^πά^ντων
# Gold:     καὶμὴνὅσἂνλέκσῃγἁ^πλῶσμνημόσυ^να^γράπσομαιγώ
# Macronizer: καὶμὴνὅσἂ_νλέκσῃγἁπλῶσμνημόσυ^να^γράπσομαιγώ
# Gold:     τί^γάρφα^θὑ_μεῖσἢνὁδί_μετῷλόγῳκρα^τήσῃ
# Macronizer: τί^γά^ρφα^θὑ_μεῖσἢνὁδί^μετῷλόγῳκρα^τήσῃ
# Gold:     τί^γάρφα^θὑ_μεῖσἢνὁδί_μετῷλόγῳκρα^τήσῃ
# Macronizer: τί^γά^ρφα^θὑ_μεῖσἢνὁδί^μετῷλόγῳκρα^τήσῃ
# Gold:     τί^γάρφα^θὑ_μεῖσἢνὁδί_μετῷλόγῳκρα^τήσῃ
# Macronizer: τί^γά^ρφα^θὑ_μεῖσἢνὁδί^μετῷλόγῳκρα^τήσῃ
# Gold:     τί^γάρφα^θὑ_μεῖσἢνὁδί_μετῷλόγῳκρα^τήσῃ
# Macronizer: τί^γά^ρφα^θὑ_μεῖσἢνὁδί^μετῷλόγῳκρα^τήσῃ
# Gold:     σκωπτόμενοιδἐνταῖσὁδοῖσθαλλοφόροικα^λούμεθἀντωμοσι^ῶνκελύ_φη
# Macronizer: σκωπτόμενοιδἐνταῖσὁδοῖσθαλλοφόροικα^λούμεθἀντωμοσιῶνκελύ_φη
# Gold:     κα^λῶσγὰ^ρᾔδεινὡσἐγὼταύτῃκρά^τιστόσεἰμι_
# Macronizer: κα^λῶσγὰ^ρᾔδεινὡσἐγὼταύτῃκρά^τι^στόσεἰμι^
# Gold:     κα^λῶσγὰ^ρᾔδεινὡσἐγὼταύτῃκρά^τιστόσεἰμι_
# Macronizer: κα^λῶσγὰ^ρᾔδεινὡσἐγὼταύτῃκρά^τι^στόσεἰμι^
# Gold:     κα^λῶσγὰ^ρᾔδεινὡσἐγὼταύτῃκρά^τιστόσεἰμι_
# Macronizer: κα^λῶσγὰ^ρᾔδεινὡσἐγὼταύτῃκρά^τι^στόσεἰμι^
# Gold:     κα^λῶσγὰ^ρᾔδεινὡσἐγὼταύτῃκρά^τιστόσεἰμι_
# Macronizer: κα^λῶσγὰ^ρᾔδεινὡσἐγὼταύτῃκρά^τι^στόσεἰμι^
# Gold:     ὥσθοὗτοσἤδησκορδι^νᾶταικἄστι^νοὐκἐναὑτοῦ
# Macronizer: ὥσθοὗτοσἤδησκορδινᾶταικἄστινοὐκἐναὑτοῦ
# Gold:     ὥσθοὗτοσἤδησκορδι^νᾶταικἄστι^νοὐκἐναὑτοῦ
# Macronizer: ὥσθοὗτοσἤδησκορδινᾶταικἄστινοὐκἐναὑτοῦ
# Gold:     εἰσἀ^πόφευκσινπα^λά^μασ
# Macronizer: εἰσἀ^πόφευκσι^νπα^λά^μα_σ
# Gold:     εἰσἀ^πόφευκσινπα^λά^μασ
# Macronizer: εἰσἀ^πόφευκσι^νπα^λά^μα_σ
# Gold:     εἰσἀ^πόφευκσινπα^λά^μασ
# Macronizer: εἰσἀ^πόφευκσι^νπα^λά^μα_σ
# Gold:     πι^θοῦπι^θοῦλόγοισι^μηδἄ^φρωνγένῃ
# Macronizer: πι^θοῦπι^θοῦλόγοισι^μηδἄφρωνγένῃ
# Gold:     εἶναίτι^σὅστιστοιαῦτἐνουθέτει
# Macronizer: εἶναίτι^σὅστι^στοιαῦτἐνουθέτει
# Gold:     κσυλλαμβά^νειτοῦπράγμα^τοσκαὶδῆλόσἐστι^νεὖποιῶν
# Macronizer: κσυ^λλα^μβά^νειτοῦπρά_γμα^τοσκαὶδῆλόσἐστι^νεὖποιῶν
# Gold:     νενουθέτηκεναὑτὸνἐστὰ^πράγμα^θοἷσ
# Macronizer: νενουθέτηκεναὑτὸνἐστὰ^πράγμα_θοἷσ
# Gold:     νενουθέτηκεναὑτὸνἐστὰ^πράγμα^θοἷσ
# Macronizer: νενουθέτηκεναὑτὸνἐστὰ^πράγμα_θοἷσ
# Gold:     τότἐπεμαίνετἔγνωκεγὰ^ρἀρτί^ωσ
# Macronizer: τότἐπεμαίνετἔγνωκεγὰ^ρἀ^ρτί^ωσ
# Gold:     λογίδσεταίτἐκεῖνα^πάνθἁ^μαρτί^ασ
# Macronizer: λογίδσεταίτἐκεῖνα^πάνθἁ^μαρτί^α_σ
# Gold:     λογίδσεταίτἐκεῖνα^πάνθἁ^μαρτί^ασ
# Macronizer: λογίδσεταίτἐκεῖνα^πάνθἁ^μαρτί^α_σ
# Gold:     λογίδσεταίτἐκεῖνα^πάνθἁ^μαρτί^ασ
# Macronizer: λογίδσεταίτἐκεῖνα^πάνθἁ^μαρτί^α_σ
# Gold:     νῦνδἴ^σωστοῖσι^σοῖσλόγοισπείθεται
# Macronizer: νῦνδἴ_σωστοῖσι^σοῖσλόγοισπείθεται
# Gold:     εὐφημί^α_μὲνπρῶτα^νῦνὑ^παρχέτω
# Macronizer: εὐφημί^α_μὲνπρῶτα^νῦνὑ^πα^ρχέτω
# Gold:     εὐφημί^α_μὲνπρῶτα^νῦνὑ^παρχέτω
# Macronizer: εὐφημί^α_μὲνπρῶτα^νῦνὑ^πα^ρχέτω
# Gold:     εὐφημί^α_μὲνπρῶτα^νῦνὑ^παρχέτω
# Macronizer: εὐφημί^α_μὲνπρῶτα^νῦνὑ^πα^ρχέτω
# Gold:     εὐφημί^α_μὲνπρῶτα^νῦνὑ^παρχέτω
# Macronizer: εὐφημί^α_μὲνπρῶτα^νῦνὑ^πα^ρχέτω
# Gold:     ὦφοῖβἄ^πολλονπύ_θι^ἐπἀ^γα^θῇτύ^χῃ
# Macronizer: ὦφοῖβἄ^πολλονπύ^θιἐπἀ^γα^θῇτύ^χῃ
# Gold:     ὦφοῖβἄ^πολλονπύ_θι^ἐπἀ^γα^θῇτύ^χῃ
# Macronizer: ὦφοῖβἄ^πολλονπύ^θιἐπἀ^γα^θῇτύ^χῃ
# Gold:     ὦφοῖβἄ^πολλονπύ_θι^ἐπἀ^γα^θῇτύ^χῃ
# Macronizer: ὦφοῖβἄ^πολλονπύ^θιἐπἀ^γα^θῇτύ^χῃ
# Gold:     φι^λοῦντοσὡσοὐδεὶσἀ^νὴρ
# Macronizer: φιλοῦντοσὡσοὐδεὶσἀ^νὴρ
# Gold:     νεα^νι^κὴνσχεῖνὡσἐγὼτοὐμὸννομίδσω
# Macronizer: νεα_νικὴνσχεῖνὡσἐγὼτοὐμὸννομίδσω
# Gold:     νεα^νι^κὴνσχεῖνὡσἐγὼτοὐμὸννομίδσω
# Macronizer: νεα_νικὴνσχεῖνὡσἐγὼτοὐμὸννομίδσω
# Gold:     γῆρα^σεἶναικρεῖττονἢπολλῶνκι^κίννουσνεα^νι^ῶνκαὶσχῆμα^κεὐρυ^πρωκτί^αν
# Macronizer: γῆρα^σεἶναικρεῖττονἢπολλῶνκι^κί^ννουσνεα_νι^ῶνκαὶσχῆμα^κεὐρυπρωκτί^αν
# Gold:     γῆρα^σεἶναικρεῖττονἢπολλῶνκι^κίννουσνεα^νι^ῶνκαὶσχῆμα^κεὐρυ^πρωκτί^αν
# Macronizer: γῆρα^σεἶναικρεῖττονἢπολλῶνκι^κί^ννουσνεα_νι^ῶνκαὶσχῆμα^κεὐρυπρωκτί^αν
# Gold:     γῆρα^σεἶναικρεῖττονἢπολλῶνκι^κίννουσνεα^νι^ῶνκαὶσχῆμα^κεὐρυ^πρωκτί^αν
# Macronizer: γῆρα^σεἶναικρεῖττονἢπολλῶνκι^κί^ννουσνεα_νι^ῶνκαὶσχῆμα^κεὐρυπρωκτί^αν
# Gold:     γῆρα^σεἶναικρεῖττονἢπολλῶνκι^κίννουσνεα^νι^ῶνκαὶσχῆμα^κεὐρυ^πρωκτί^αν
# Macronizer: γῆρα^σεἶναικρεῖττονἢπολλῶνκι^κί^ννουσνεα_νι^ῶνκαὶσχῆμα^κεὐρυπρωκτί^αν
# Gold:     ἆρα^δεινὸσἦτόθὥστεπάντα^μὴδεδοικέναι
# Macronizer: ἆρα^δεινὸσἦτόθὥστεπά^ντα^μὴδεδοικέναι
# Gold:     φροντί^σἀλλὅστι^σἐρέτησἔσοιτἄ^ριστοσ
# Macronizer: φροντί^σἀλλὅστι^σἐρέτησἔσοιτἄ^ρι^στοσ
# Gold:     φροντί^σἀλλὅστι^σἐρέτησἔσοιτἄ^ριστοσ
# Macronizer: φροντί^σἀλλὅστι^σἐρέτησἔσοιτἄ^ρι^στοσ
# Gold:     φροντί^σἀλλὅστι^σἐρέτησἔσοιτἄ^ριστοσ
# Macronizer: φροντί^σἀλλὅστι^σἐρέτησἔσοιτἄ^ρι^στοσ
# Gold:     τοιγα^ροῦνπολλὰσπόλεισμήδωνἑλόντεσ
# Macronizer: τοιγα^ροῦνπολλὰ_σπόλεισμήδωνἑλόντεσ
# Gold:     δσηλῶγετῆσεὐτυ^χί^ασ
# Macronizer: δσηλῶγετῆσεὐτυ^χί^α_σ
# Gold:     δσηλῶγετῆσεὐτυ^χί^ασ
# Macronizer: δσηλῶγετῆσεὐτυ^χί^α_σ
# Gold:     κσηρῶντρόπωνκαὶβι^οτῆσἕτερα^δὲνῦνἀντι^μα^θὼν
# Macronizer: κσηρῶντρόπωνκαὶβιοτῆσἕτερα^δὲνῦνἀντιμα^θὼν
# Gold:     κσηρῶντρόπωνκαὶβι^οτῆσἕτερα^δὲνῦνἀντι^μα^θὼν
# Macronizer: κσηρῶντρόπωνκαὶβιοτῆσἕτερα^δὲνῦνἀντιμα^θὼν
# Gold:     τά^χα^δἂ^νἴ^σωσοὐκἐθέλοι
# Macronizer: τά^χα^δἂ^νἴ_σωσοὐκἐθέλοι
# Gold:     τά^χα^δἂ^νἴ^σωσοὐκἐθέλοι
# Macronizer: τά^χα^δἂ^νἴ_σωσοὐκἐθέλοι
# Gold:     τά^χα^δἂ^νἴ^σωσοὐκἐθέλοι
# Macronizer: τά^χα^δἂ^νἴ_σωσοὐκἐθέλοι
# Gold:     καὶτοῖσι^νεὖφρονοῦσιν
# Macronizer: καὶτοῖσι^νεὖφρονοῦσι^ν
# Gold:     τυ^χὼνἄ^πεισινδι^ὰ^τὴνφι^λοπα^τρί^ανκαὶσοφί^αν
# Macronizer: τυ^χὼνἄ^πεισι^νδι^ὰ^τὴνφιλοπατρί^ανκαὶσοφί^α_ν
# Gold:     τυ^χὼνἄ^πεισινδι^ὰ^τὴνφι^λοπα^τρί^ανκαὶσοφί^αν
# Macronizer: τυ^χὼνἄ^πεισι^νδι^ὰ^τὴνφιλοπατρί^ανκαὶσοφί^α_ν
# Gold:     τυ^χὼνἄ^πεισινδι^ὰ^τὴνφι^λοπα^τρί^ανκαὶσοφί^αν
# Macronizer: τυ^χὼνἄ^πεισι^νδι^ὰ^τὴνφιλοπατρί^ανκαὶσοφί^α_ν
# Gold:     τυ^χὼνἄ^πεισινδι^ὰ^τὴνφι^λοπα^τρί^ανκαὶσοφί^αν
# Macronizer: τυ^χὼνἄ^πεισι^νδι^ὰ^τὴνφιλοπατρί^ανκαὶσοφί^α_ν
# Gold:     τυ^χὼνἄ^πεισινδι^ὰ^τὴνφι^λοπα^τρί^ανκαὶσοφί^αν
# Macronizer: τυ^χὼνἄ^πεισι^νδι^ὰ^τὴνφιλοπατρί^ανκαὶσοφί^α_ν
# Gold:     τυ^χὼνἄ^πεισινδι^ὰ^τὴνφι^λοπα^τρί^ανκαὶσοφί^αν
# Macronizer: τυ^χὼνἄ^πεισι^νδι^ὰ^τὴνφιλοπατρί^ανκαὶσοφί^α_ν
# Gold:     τυ^χὼνἄ^πεισινδι^ὰ^τὴνφι^λοπα^τρί^ανκαὶσοφί^αν
# Macronizer: τυ^χὼνἄ^πεισι^νδι^ὰ^τὴνφιλοπατρί^ανκαὶσοφί^α_ν
# Gold:     ὁπαῖσὁφι^λοκλέωνοσ
# Macronizer: ὁπαῖσὁφιλοκλέωνοσ
# Gold:     τί^γὰ^ρἐκεῖνοσἀντι^λέγων
# Macronizer: τί^γὰ^ρἐκεῖνοσἀντιλέγων
# Gold:     τὸνφύ_σαντα^σεμνοτέροισκα^τα^κοσμῆσαιπράγμα^σιν
# Macronizer: τὸνφύ_σα^ντα^σεμνοτέροισκα^τα^κοσμῆσαιπρά_γμα^σι^ν
# Gold:     τὸνφύ_σαντα^σεμνοτέροισκα^τα^κοσμῆσαιπράγμα^σιν
# Macronizer: τὸνφύ_σα^ντα^σεμνοτέροισκα^τα^κοσμῆσαιπρά_γμα^σι^ν
# Gold:     τὸνφύ_σαντα^σεμνοτέροισκα^τα^κοσμῆσαιπράγμα^σιν
# Macronizer: τὸνφύ_σα^ντα^σεμνοτέροισκα^τα^κοσμῆσαιπρά_γμα^σι^ν
# Gold:     τὸνφύ_σαντα^σεμνοτέροισκα^τα^κοσμῆσαιπράγμα^σιν
# Macronizer: τὸνφύ_σα^ντα^σεμνοτέροισκα^τα^κοσμῆσαιπρά_γμα^σι^ν
# Gold:     τὸνφύ_σαντα^σεμνοτέροισκα^τα^κοσμῆσαιπράγμα^σιν
# Macronizer: τὸνφύ_σα^ντα^σεμνοτέροισκα^τα^κοσμῆσαιπρά_γμα^σι^ν
#
# === File: norma_aristophanis_canticorum.txt ===
# ^ success: 1883/3032 = 0.6210
# _ success: 147/391 = 0.3760
# Both success: 2030/3423 = 0.5930
# Line matches ignoring ^_: 1063/1063 = 1.0000
# Gold:     ἔστι^τι^σσι^ῶντί^σι^σ
# Macronizer: ἔστι^τι^σσι^ῶντί^σισ
# Gold:     ἁ_μέρα_νδι^α^πλέκει
# Macronizer: ἁ_μέρανδιαπλέκει
# Gold:     ἁ_μέρα_νδι^α^πλέκει
# Macronizer: ἁ_μέρανδιαπλέκει
# Gold:     ἁ_μέρα_νδι^α^πλέκει
# Macronizer: ἁ_μέρανδιαπλέκει
# Gold:     ἄ^κλαυτοσἐγὼνδἀ^είδω
# Macronizer: ἄκλαυτοσἐγὼνδἀ^είδω
# Gold:     ἀ_γι^δῶστὸφῶσὁρῶ
# Macronizer: ἀ^γιδῶστὸφῶσὁρῶ
# Gold:     ἀ_γι^δῶστὸφῶσὁρῶ
# Macronizer: ἀ^γιδῶστὸφῶσὁρῶ
# ϝὥτἄλιονὅνπερἇμιν
# ≠
# ὥτἄλιονὅνπερἇμιν
#
# Gold:     ϝὥτἄ_λι^ονὅνπερἇμι_ν
# Macronizer: ὥτἄ^λιονὅνπερἇμι^ν
# Gold:     ϝὥτἄ_λι^ονὅνπερἇμι_ν
# Macronizer: ὥτἄ^λιονὅνπερἇμι^ν
# Gold:     ϝὥτἄ_λι^ονὅνπερἇμι_ν
# Macronizer: ὥτἄ^λιονὅνπερἇμι^ν
# Gold:     ἀ_γι^δὼμαρτύ_ρεται
# Macronizer: ἀ^γιδὼμαρτύ^ρεται
# Gold:     ἀ_γι^δὼμαρτύ_ρεται
# Macronizer: ἀ^γιδὼμαρτύ^ρεται
# Gold:     ἀ_γι^δὼμαρτύ_ρεται
# Macronizer: ἀ^γιδὼμαρτύ^ρεται
# Gold:     οὔτεμωμήσθαινι^νἁ_κλεννὰ_χορα_γὸσ
# Macronizer: οὔτεμωμήσθαινινἁ_κλεννὰ^χορα^γὸσ
# Gold:     οὔτεμωμήσθαινι^νἁ_κλεννὰ_χορα_γὸσ
# Macronizer: οὔτεμωμήσθαινινἁ_κλεννὰ^χορα^γὸσ
# Gold:     οὔτεμωμήσθαινι^νἁ_κλεννὰ_χορα_γὸσ
# Macronizer: οὔτεμωμήσθαινινἁ_κλεννὰ^χορα^γὸσ
# Gold:     οὔτεμωμήσθαινι^νἁ_κλεννὰ_χορα_γὸσ
# Macronizer: οὔτεμωμήσθαινινἁ_κλεννὰ^χορα^γὸσ
# Gold:     οὐδἁ^μῶσἐῆιδοκεῖγὰ^ρἤμεναὔτα_
# Macronizer: οὐδἁ_μῶσἐῆιδοκεῖγὰ^ρἤμεναὔτα^
# Gold:     οὐδἁ^μῶσἐῆιδοκεῖγὰ^ρἤμεναὔτα_
# Macronizer: οὐδἁ_μῶσἐῆιδοκεῖγὰ^ρἤμεναὔτα^
# Gold:     οὐδἁ^μῶσἐῆιδοκεῖγὰ^ρἤμεναὔτα_
# Macronizer: οὐδἁ_μῶσἐῆιδοκεῖγὰ^ρἤμεναὔτα^
# Gold:     ἐκπρεπὴστὼσὥπεραἴτι^σἐνβοτοῖσστά_σειενἵππον
# Macronizer: ἐκπρεπὴστὼσὥπεραἴτι^σἐνβοτοῖσστά^σειενἵππον
# Gold:     ἐκπρεπὴστὼσὥπεραἴτι^σἐνβοτοῖσστά_σειενἵππον
# Macronizer: ἐκπρεπὴστὼσὥπεραἴτι^σἐνβοτοῖσστά^σειενἵππον
# Gold:     πα_γὸνἀ^εθλοφόρονκα^να^χά_ποδα^
# Macronizer: πα^γὸνἀ^εθλοφόρονκα^να^χά^ποδα^
# Gold:     πα_γὸνἀ^εθλοφόρονκα^να^χά_ποδα^
# Macronizer: πα^γὸνἀ^εθλοφόρονκα^να^χά^ποδα^
# Gold:     πα_γὸνἀ^εθλοφόρονκα^να^χά_ποδα^
# Macronizer: πα^γὸνἀ^εθλοφόρονκα^να^χά^ποδα^
# Gold:     πα_γὸνἀ^εθλοφόρονκα^να^χά_ποδα^
# Macronizer: πα^γὸνἀ^εθλοφόρονκα^να^χά^ποδα^
# Gold:     πα_γὸνἀ^εθλοφόρονκα^να^χά_ποδα^
# Macronizer: πα^γὸνἀ^εθλοφόρονκα^να^χά^ποδα^
# Gold:     τῶνὑ^ποπετρι^δί^ωνὀνείρων
# Macronizer: τῶνὑ^ποπετριδί^ωνὀνείρων
#
# === File: partheneion.txt ===
# ^ success: 10/25 = 0.4000
# _ success: 1/14 = 0.0714
# Both success: 11/39 = 0.2821
# Line matches ignoring ^_: 12/13 = 0.9231
# Gold:     ἁ_γὼδι^καιῶνμὴπα^ρἀγγέλωντέκνα^
# Macronizer: ἁ^γὼδι^καιῶνμὴπα^ρἀγγέλωντέκνα^
# Gold:     εἴηντοιάνδεμὴοὐκα^τοικτί_ρωνἕδρα_ν
# Macronizer: εἴηντοιάνδεμὴοὐκα^τοικτί^ρωνἕδραν
# Gold:     εἴηντοιάνδεμὴοὐκα^τοικτί_ρωνἕδρα_ν
# Macronizer: εἴηντοιάνδεμὴοὐκα^τοικτί^ρωνἕδραν
# Gold:     εἴηντοιάνδεμὴοὐκα^τοικτί_ρωνἕδρα_ν
# Macronizer: εἴηντοιάνδεμὴοὐκα^τοικτί^ρωνἕδραν
# Gold:     ἀ^γοραῖσι^θα_κεῖπρόστεπαλλά^δοσδι^πλοῖσ
# Macronizer: ἀ^γοραῖσι^θα^κεῖπρόστεπαλλά^δοσδιπλοῖσ
# Gold:     ἀ^γοραῖσι^θα_κεῖπρόστεπαλλά^δοσδι^πλοῖσ
# Macronizer: ἀ^γοραῖσι^θα^κεῖπρόστεπαλλά^δοσδιπλοῖσ
# Gold:     ἀ^γοραῖσι^θα_κεῖπρόστεπαλλά^δοσδι^πλοῖσ
# Macronizer: ἀ^γοραῖσι^θα^κεῖπρόστεπαλλά^δοσδιπλοῖσ
# Gold:     ἀ^γοραῖσι^θα_κεῖπρόστεπαλλά^δοσδι^πλοῖσ
# Macronizer: ἀ^γοραῖσι^θα^κεῖπρόστεπαλλά^δοσδιπλοῖσ
#
# === File: oedipus.txt ===
# ^ success: 38/42 = 0.9048
# _ success: 10/14 = 0.7143
# Both success: 48/56 = 0.8571
# Line matches ignoring ^_: 20/20 = 1.0000
# Gold:     θουκυ_δί^δησἀ^θηναῖοσκσυ^νέγρα^πσετὸνπόλεμοντῶνπελοποννησί^ων
# Macronizer: θουκυ^δί^δησἀ^θηναῖοσκσυ^νέγρα^πσετὸνπόλεμοντῶνπελοποννησί^ων
# Gold:     περι^ουσί^α_νχρημά^τωνοὐκἔχοντεσοὐδὲγῆνφυ^τεύοντεσ
# Macronizer: περι^ουσί^ανχρημά^τωνοὐκἔχοντεσοὐδὲγῆνφυ^τεύοντεσ
#
# === File: thucydides.txt ===
# ^ success: 88/88 = 1.0000
# _ success: 4/6 = 0.6667
# Both success: 92/94 = 0.9787
# Line matches ignoring ^_: 20/20 = 1.0000
# Gold:     καλλι^όπηφα^έθοντα^τὸνεὐ_ρυ^φά^εσσα^βοῶπι_σ
# Macronizer: καλλιόπηφα^έθοντα^τὸνεὐ^ρυ^φά^εσσα^βοῶπι^σ
# Gold:     καλλι^όπηφα^έθοντα^τὸνεὐ_ρυ^φά^εσσα^βοῶπι_σ
# Macronizer: καλλιόπηφα^έθοντα^τὸνεὐ^ρυ^φά^εσσα^βοῶπι^σ
# Gold:     καλλι^όπηφα^έθοντα^τὸνεὐ_ρυ^φά^εσσα^βοῶπι_σ
# Macronizer: καλλιόπηφα^έθοντα^τὸνεὐ^ρυ^φά^εσσα^βοῶπι^σ
# Gold:     καλλι^όπηφα^έθοντα^τὸνεὐ_ρυ^φά^εσσα^βοῶπι_σ
# Macronizer: καλλιόπηφα^έθοντα^τὸνεὐ^ρυ^φά^εσσα^βοῶπι^σ
# Gold:     καλλι^όπηφα^έθοντα^τὸνεὐ_ρυ^φά^εσσα^βοῶπι_σ
# Macronizer: καλλιόπηφα^έθοντα^τὸνεὐ^ρυ^φά^εσσα^βοῶπι^σ
# Gold:     καλλι^όπηφα^έθοντα^τὸνεὐ_ρυ^φά^εσσα^βοῶπι_σ
# Macronizer: καλλιόπηφα^έθοντα^τὸνεὐ^ρυ^φά^εσσα^βοῶπι^σ
# Gold:     γῆμεγὰ^ρεὐ_ρυ^φά^εσσα^νἀ^γακλειτὴνὑ^περί_ων
# Macronizer: γῆμεγὰ^ρεὐ^ρυ^φά^εσσα^νἀ^γα^κλειτὴνὑ^περί^ων
# Gold:     γῆμεγὰ^ρεὐ_ρυ^φά^εσσα^νἀ^γακλειτὴνὑ^περί_ων
# Macronizer: γῆμεγὰ^ρεὐ^ρυ^φά^εσσα^νἀ^γα^κλειτὴνὑ^περί^ων
# Gold:     γῆμεγὰ^ρεὐ_ρυ^φά^εσσα^νἀ^γακλειτὴνὑ^περί_ων
# Macronizer: γῆμεγὰ^ρεὐ^ρυ^φά^εσσα^νἀ^γα^κλειτὴνὑ^περί^ων
# Gold:     γῆμεγὰ^ρεὐ_ρυ^φά^εσσα^νἀ^γακλειτὴνὑ^περί_ων
# Macronizer: γῆμεγὰ^ρεὐ^ρυ^φά^εσσα^νἀ^γα^κλειτὴνὑ^περί^ων
# Gold:     γῆμεγὰ^ρεὐ_ρυ^φά^εσσα^νἀ^γακλειτὴνὑ^περί_ων
# Macronizer: γῆμεγὰ^ρεὐ^ρυ^φά^εσσα^νἀ^γα^κλειτὴνὑ^περί^ων
# Gold:     γῆμεγὰ^ρεὐ_ρυ^φά^εσσα^νἀ^γακλειτὴνὑ^περί_ων
# Macronizer: γῆμεγὰ^ρεὐ^ρυ^φά^εσσα^νἀ^γα^κλειτὴνὑ^περί^ων
# Gold:     αὐτοκα^σιγνήτηνἥοἱτέκεκάλλι^μα^τέκνα^
# Macronizer: αὐτοκα^σιγνήτηνἥοἱτέκεκάλλιμα^τέκνα^
# Gold:     τηλαυγέσκα_λὸνδὲπερὶ^χροῒ^λάμπεταιἔσθοσ
# Macronizer: τηλαυγέσκα^λὸνδὲπερὶ^χροῒ^λάμπεταιἔσθοσ
# Gold:     ἔνθἄ^ρὅγεστήσα_σχρυ_σόδσυ^γονἅ^ρμα^καὶἵππουσ
# Macronizer: ἔνθἄ^ρὅγεστήσα_σχρυ_σόδσυ^γονἅρμα^καὶἵππουσ
# Gold:     θεσπέσι^οσπέμπῃσι^δι^οὐρα^νοῦὠκεα^νὸνδέ
# Macronizer: θεσπέσι^οσπέμπῃσιδι^οὐρα^νοῦὠκεα^νὸνδέ
# Gold:     ἡμι^θέωνὧνἔργα^θεοὶθνητοῖσι^νἔδεικσα^ν
# Macronizer: ἡμιθέωνὧνἔργα^θεοὶθνητοῖσι^νἔδεικσα^ν
#
# === File: insolem.txt ===
# ^ success: 58/70 = 0.8286
# _ success: 7/12 = 0.5833
# Both success: 65/82 = 0.7927
# Line matches ignoring ^_: 19/19 = 1.0000
# Gold:     ὦβρόμι^εδι^ὰ^σὲμυ_ρί^ουσἔχωπόνουσ
# Macronizer: ὦβρόμιεδι^ὰ^σὲμυ_ρί^ουσἔχωπόνουσ
# Gold:     ἐνδέκσι^οσσῶιποδὶ^πα^ρασπιστὴσβεβὼσ
# Macronizer: ἐνδέκσιοσσῶιποδὶ^πα^ρασπιστὴσβεβὼσ
# Gold:     ἐγκέλα^δονἰ_τέα^νἐσμέσηνθενὼνδορὶ^
# Macronizer: ἐγκέλα^δονἰ_τέα_νἐσμέσηνθενὼνδορὶ^
# Gold:     ἐγκέλα^δονἰ_τέα^νἐσμέσηνθενὼνδορὶ^
# Macronizer: ἐγκέλα^δονἰ_τέα_νἐσμέσηνθενὼνδορὶ^
# Gold:     ἐγκέλα^δονἰ_τέα^νἐσμέσηνθενὼνδορὶ^
# Macronizer: ἐγκέλα^δονἰ_τέα_νἐσμέσηνθενὼνδορὶ^
# Gold:     ἤδηδὲμα^λέα_σπλησί^ονπεπλευκότα^σ
# Macronizer: ἤδηδὲμα^λέασπλησί^ονπεπλευκότα^σ
# Gold:     ἐκσέβα^λενἡμᾶστήνδἐσαἰτναία_νπέτρα_ν
# Macronizer: ἐκσέβα^λενἡμᾶστήνδἐσα^ἰτναίανπέτραν
# Gold:     ἐκσέβα^λενἡμᾶστήνδἐσαἰτναία_νπέτρα_ν
# Macronizer: ἐκσέβα^λενἡμᾶστήνδἐσα^ἰτναίανπέτραν
# Gold:     ἐκσέβα^λενἡμᾶστήνδἐσαἰτναία_νπέτρα_ν
# Macronizer: ἐκσέβα^λενἡμᾶστήνδἐσα^ἰτναίανπέτραν
#
# === File: cyclops.txt ===
# ^ success: 45/50 = 0.9000
# _ success: 8/12 = 0.6667
# Both success: 53/62 = 0.8548
# Line matches ignoring ^_: 20/20 = 1.0000
#
# === Global summary ===
# ^ success: 2555/3877 = 0.6590
# _ success: 221/527 = 0.4194
# Both success: 2776/4404 = 0.6303
# Line matches ignoring ^_: 1294/1295 = 0.9992

# %% [markdown]
# NOTE: in article, also compare with best result possible with (finetuned/vanilla?) GPT-5?
#
# Intressant att makronizer-mini ibland makroniserar stängda mcl: ἐνβι^βλί^ῳ

# %%
import grc_odycy_joint_trf

nlp = grc_odycy_joint_trf.load()

nlp.pipe(sentence_list)
